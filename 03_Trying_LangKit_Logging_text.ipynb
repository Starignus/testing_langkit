# %% [markdown]
# <a href="https://colab.research.google.com/github/Starignus/testing_langkit/blob/main/03_Trying_LangKit_Logging_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Investigating LangKit
#
# [LangKit is an open-source](https://github.com/whylabs/langkit/tree/main) text metrics toolkit for monitoring language models. It offers an array of methods for extracting relevant signals from the input and/or output text, which are compatible with the open-source data logging library [whylogs](https://whylogs.readthedocs.io/en/latest/).
#
# [LangKit can monitor and safeguard](https://whylabs.ai/blog/posts/langkit-making-large-language-models-safe-and-responsible) your LLMs by quickly detecting and preventing malicious prompts, toxicity, hallucinations, and jailbreak attempts. You can check the [metrics that covers](https://github.com/whylabs/langkit/blob/main/langkit/docs/modules.md).
#
# First let's install the required libraries.

# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.1.0+cu121)
# Requirement already satisfied: accelerate>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.26.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)

# %%
# !pip install langkit[all]
# Out:
# Requirement already satisfied: langkit[all] in /usr/local/lib/python3.10/dist-packages (0.0.29)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.5.3)
# Requirement already satisfied: textstat<0.8.0,>=0.7.3 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (0.7.3)
# Requirement already satisfied: whylogs<2.0.0,>=1.3.19 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.3.22)
# Requirement already satisfied: datasets<3.0.0,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.16.1)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (0.4.1)
# Requirement already satisfied: faiss-cpu<2.0.0,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.7.4)
# Requirement already satisfied: h5py<4.0.0,>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (3.10.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.1.1 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (8.1.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.23.5)
# Requirement already satisfied: openai<2.0.0,>=0.27.6 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.10.0)
# Requirement already satisfied: presidio-analyzer<3.0.0,>=2.2.351 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.2.352)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.3.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.1.0+cu121)
# Requirement already satisfied: vadersentiment<4.0.0,>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (3.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.13.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate<0.5.0,>=0.4.0->langkit[all]) (0.18.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.9)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (2023.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.10.14)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (4.9.0)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.6.1)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (5.1.1)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (8.13.29)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (4.35.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.11.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (0.1.99)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (9.4.0)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat<0.8.0,>=0.7.3->langkit[all]) (0.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (2.1.0)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.20.3)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.30.0.0 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (2.31.0.20240125)
# Requirement already satisfied: whylabs-client<0.6.0,>=0.5.10 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (0.5.10)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.4.1.dev3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->langkit[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->langkit[all]) (2023.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (4.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (0.14.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->langkit[all]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.12.0->langkit[all]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.12.0->langkit[all]) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (6.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->langkit[all]) (2.1.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->langkit[all]) (1.3.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.8.3)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.13)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.1.4)

# %%
# !pip install huggingface-hub==0.20.2
# Out:
# Requirement already satisfied: huggingface-hub==0.20.2 in /usr/local/lib/python3.10/dist-packages (0.20.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.2) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.2) (2023.11.17)

# %%
# !pip install bigframes==0.18.0
# Out:
# Requirement already satisfied: bigframes==0.18.0 in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: cloudpickle>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2.2.1)
# Requirement already satisfied: fsspec>=2023.3.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2023.6.0)
# Requirement already satisfied: gcsfs>=2023.3.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2023.6.0)
# Requirement already satisfied: geopandas>=0.12.2 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (0.13.2)
# Requirement already satisfied: google-auth<3.0dev,>2.14.1 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2.17.3)
# Requirement already satisfied: google-cloud-bigquery[bqstorage,pandas]>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (3.12.0)
# Requirement already satisfied: google-cloud-functions>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (1.13.3)
# Requirement already satisfied: google-cloud-bigquery-connection>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (1.12.1)
# Requirement already satisfied: google-cloud-iam>=2.12.1 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2.13.0)
# Requirement already satisfied: google-cloud-resource-manager>=1.10.3 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (1.11.0)
# Requirement already satisfied: google-cloud-storage>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2.8.0)
# Requirement already satisfied: ibis-framework[bigquery]<7.2.0dev,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (7.1.0)
# Requirement already satisfied: pandas<2.1.4,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (1.5.3)
# Requirement already satisfied: pydata-google-auth>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (1.8.2)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (1.2.2)
# Requirement already satisfied: sqlalchemy<3.0dev,>=1.4 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (2.0.24)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (0.9.0)
# Requirement already satisfied: ipywidgets>=7.7.1 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (8.1.1)
# Requirement already satisfied: humanize>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from bigframes==0.18.0) (4.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from gcsfs>=2023.3.0->bigframes==0.18.0) (3.9.3)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs>=2023.3.0->bigframes==0.18.0) (4.4.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (from gcsfs>=2023.3.0->bigframes==0.18.0) (1.2.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12.2->bigframes==0.18.0) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12.2->bigframes==0.18.0) (23.2)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12.2->bigframes==0.18.0) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12.2->bigframes==0.18.0) (2.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>2.14.1->bigframes==0.18.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>2.14.1->bigframes==0.18.0) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>2.14.1->bigframes==0.18.0) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>2.14.1->bigframes==0.18.0) (4.9)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery-connection>=1.12.0->bigframes==0.18.0) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery-connection>=1.12.0->bigframes==0.18.0) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery-connection>=1.12.0->bigframes==0.18.0) (3.20.3)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery-connection>=1.12.0->bigframes==0.18.0) (0.13.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (1.60.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (2.7.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (2.8.2)
# Requirement already satisfied: pyarrow>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (10.0.1)
# Requirement already satisfied: db-dtypes<2.0.0dev,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (1.2.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0.0dev,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (2.24.0)
# Requirement already satisfied: atpublic<5,>=2.3 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (4.0)
# Requirement already satisfied: bidict<1,>=0.22.1 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (0.22.1)
# Requirement already satisfied: filelock<4,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (3.13.1)
# Requirement already satisfied: multipledispatch<2,>=0.6 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (1.0.0)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (1.23.5)
# Requirement already satisfied: parsy<3,>=2 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (2.1)
# Requirement already satisfied: pins[gcs]<1,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (0.8.4)
# Requirement already satisfied: pyarrow-hotfix<1,>=0.4 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (0.6)
# Requirement already satisfied: pytz>=2022.7 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (2023.4)
# Requirement already satisfied: rich<14,>=12.4.4 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (13.7.0)
# Requirement already satisfied: sqlglot<20,>=18.12.0 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (19.9.0)
# Requirement already satisfied: toolz<1,>=0.11 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (0.12.1)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->bigframes==0.18.0) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->bigframes==0.18.0) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->bigframes==0.18.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->bigframes==0.18.0) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->bigframes==0.18.0) (3.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pydata-google-auth>=1.8.2->bigframes==0.18.0) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->bigframes==0.18.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->bigframes==0.18.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->bigframes==0.18.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->bigframes==0.18.0) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->bigframes==0.18.0) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->bigframes==0.18.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->bigframes==0.18.0) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3.0dev,>=1.4->bigframes==0.18.0) (3.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes==0.18.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes==0.18.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes==0.18.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes==0.18.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes==0.18.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes==0.18.0) (4.0.3)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12.2->bigframes==0.18.0) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12.2->bigframes==0.18.0) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12.2->bigframes==0.18.0) (0.7.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-connection>=1.12.0->bigframes==0.18.0) (1.62.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-bigquery-connection>=1.12.0->bigframes==0.18.0) (1.48.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib->gcsfs>=2023.3.0->bigframes==0.18.0) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery[bqstorage,pandas]>=3.10.0->bigframes==0.18.0) (1.5.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.19.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (4.9.0)
# Requirement already satisfied: pyyaml>=3.13 in /usr/local/lib/python3.10/dist-packages (from pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (6.0.1)
# Requirement already satisfied: xxhash>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (3.4.1)
# Requirement already satisfied: jinja2>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.10/dist-packages (from pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (7.0.1)
# Requirement already satisfied: importlib-resources>=1.3 in /usr/local/lib/python3.10/dist-packages (from pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (6.1.1)
# Requirement already satisfied: appdirs<2.0.0 in /usr/local/lib/python3.10/dist-packages (from pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (1.4.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>2.14.1->bigframes==0.18.0) (0.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=12.4.4->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (3.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.4->pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.0->pins[gcs]<1,>=0.8.3->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (2.1.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=12.4.4->ibis-framework[bigquery]<7.2.0dev,>=7.1.0->bigframes==0.18.0) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes==0.18.0) (0.2.13)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2023.3.0->bigframes==0.18.0) (3.2.2)

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
! pip install datasets==2.16.1
# Out:
# Requirement already satisfied: datasets==2.16.1 in /usr/local/lib/python3.10/dist-packages (2.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.16.1) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.16.1) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets==2.16.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.16.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.16.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.16.1) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.16.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.16.1) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets==2.16.1) (1.16.0)

# %% [markdown]
# # [Loging text](https://github.com/whylabs/langkit/blob/main/langkit/examples/Intro_to_Langkit.ipynb)

# %%
# Path where the models from huggingface are downloaded before importing
# !ls ~/.cache/
# Out:
# huggingface  matplotlib  node-gyp  pip

# %%
import whylogs as why
from langkit import light_metrics

llm_schema = light_metrics.init()
print("Done initializing metrics.")
# Out:
# Done initializing metrics.

# %%
# Path where the models from huggingface are downloaded
# !ls ~/.cache/huggingface/hub/
# Out:
# models--martin-ha--toxic-comment-model		 version.txt
# models--sentence-transformers--all-MiniLM-L6-v2

# %%
#  Path where the nltk data is downloaded
# !ls /root/nltk_data/sentiment
# Out:
# vader_lexicon.zip

# %% [markdown]
# ```light_metrics``` is composed by the following modules:
#
# * ```textstat```: Text quality, readability, complexity, and grade level.
# * ```regexes```: Regex pattern matching for sensitive information
#
# We cans see that importing the metrics, some models where downloaded. You can check details on the models and submodules used for the text statistics and regular expresion search paterns in the [documentation](https://github.com/whylabs/langkit/blob/main/langkit/docs/modules.md). The regexes can be customised and is a json file ```pattern_groups.json```.

# %% [markdown]
# # Feature Extraction
#
# Langkit can be used to extract features from text data. The llm_schema created previously will guide the feature extraction process.

# %%
from langkit import extract
import pandas as pd

# %%
df = pd.DataFrame({'prompt': ['Hello', 'What is your number?', 'What is your adress?'],
                   'response': ['World','my phone is +1 309-404-7587', 'my adress is 304 Brown streest W1 0F3']})

# %%
df
# Out:
#                  prompt                               response
# 0                 Hello                                  World
# 1  What is your number?            my phone is +1 309-404-7587
# 2  What is your adress?  my adress is 304 Brown streest W1 0F3

# %%
enhanced_df = extract(df, schema=llm_schema)

enhanced_df
# Out:
#                  prompt                               response  \
# 0                 Hello                                  World
# 1  What is your number?            my phone is +1 309-404-7587
# 2  What is your adress?  my adress is 304 Brown streest W1 0F3
#
#    prompt.flesch_reading_ease  response.flesch_reading_ease  \
# 0                       36.62                        121.22
# 1                       92.80                        117.16
# 2                      118.18                        114.12
#
#    prompt.automated_readability_index  response.automated_readability_index  \
# 0                                 2.6                                   2.6
# 1                                 0.6                                   2.7
# 2                                 0.6                                   0.2
#
#    prompt.aggregate_reading_level  response.aggregate_reading_level  \
# 0                             0.0                               0.0
# 1                             1.0                               2.0
# 2                             0.0                               0.0
#
#    prompt.syllable_count  response.syllable_count  ...  prompt.letter_count  \
# 0                      2                        1  ...                    5
# 1                      5                        5  ...                   16
# 2                      4                        8  ...                   16
#
#    response.letter_count  prompt.polysyllable_count  \
# 0                      5                          0
# 1                     20                          0
# 2                     30                          0
#
#    response.polysyllable_count  prompt.monosyllable_count  \
# 0                            0                          0
# 1                            0                          3
# 2                            0                          4
#
#    response.monosyllable_count  prompt.difficult_words  \
# 0                            1                       0
# 1                            5                       0
# 2                            8                       0
#
#    response.difficult_words  prompt.has_patterns  response.has_patterns
# 0                         0                 None                   None
# 1                         0                 None           phone number
# 2                         0                 None                   None
#
# [3 rows x 26 columns]

# %% [markdown]
# You can also pass a *dictionary*.

# %%
enhanced_row = extract({"prompt": "What is your number?","response": "my phone is +1 309-404-7587"},
                       schema=llm_schema)
enhanced_row
# Out:
# {'prompt': 'What is your number?',
#  'response': 'my phone is +1 309-404-7587',
#  'prompt.flesch_reading_ease': 92.8,
#  'response.flesch_reading_ease': 117.16,
#  'prompt.automated_readability_index': 0.6,
#  'response.automated_readability_index': 2.7,
#  'prompt.aggregate_reading_level': 1.0,
#  'response.aggregate_reading_level': 2.0,
#  'prompt.syllable_count': 5,
#  'response.syllable_count': 5,
#  'prompt.lexicon_count': 4,
#  'response.lexicon_count': 5,
#  'prompt.sentence_count': 1,
#  'response.sentence_count': 1,
#  'prompt.character_count': 17,
#  'response.character_count': 23,
#  'prompt.letter_count': 16,
#  'response.letter_count': 20,
#  'prompt.polysyllable_count': 0,
#  'response.polysyllable_count': 0,
#  'prompt.monosyllable_count': 3,
#  'response.monosyllable_count': 5,
#  'prompt.difficult_words': 0,
#  'response.difficult_words': 0,
#  'prompt.has_patterns': None,
#  'response.has_patterns': 'phone number'}

# %% [markdown]
# # Statistical Profiling with whylogs
#
# LangKit modules contain UDFs that automatically wire into the collection of UDFs on String features provided by whylogs by default.
#
# All we have to do is pass the schema to ```why.log()```:

# %%
# Initialize a session and authenticate
why.init()
# Out:
# ❓ What kind of session do you want to use?
#  ⤷ 1. WhyLabs. Use an api key to upload to WhyLabs.
#  ⤷ 2. WhyLabs Anonymous. Upload data anonymously to WhyLabs and get a viewing url.
#
# Enter a number from the list: 2
# Initializing session with config /root/.config/whylogs/config.ini
#
# ✅ Using session type: WHYLABS_ANONYMOUS
#  ⤷ session id: <will be generated before upload>

# %%
results = why.log({"prompt": "Hello,", "response": "World!"}, schema=llm_schema)
print("Done profiling! Let's look at some of the metrics:")
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-1/profiles?profile=1706832000000&sessionToken=session-PqLk2vsP
# Done profiling! Let's look at some of the metrics:

# %%
view = results.view()
for col_name in view.get_columns():
    print(col_name)
print()
print("Here is the summary for response metrics")
view.get_column("response").to_summary_dict()
# Out:
# prompt
# response
# prompt.flesch_reading_ease
# response.flesch_reading_ease
# prompt.automated_readability_index
# response.automated_readability_index
# prompt.aggregate_reading_level
# response.aggregate_reading_level
# prompt.syllable_count
# response.syllable_count
# prompt.lexicon_count
# response.lexicon_count
# prompt.sentence_count
# response.sentence_count
# prompt.character_count
# response.character_count
# prompt.letter_count
# response.letter_count
# prompt.polysyllable_count
# response.polysyllable_count
# prompt.monosyllable_count
# response.monosyllable_count
# prompt.difficult_words
# response.difficult_words
# prompt.has_patterns
# response.has_patterns
#
# Here is the summary for response metrics
# {'counts/n': 1,
#  'counts/null': 0,
#  'counts/nan': 0,
#  'counts/inf': 0,
#  'types/integral': 0,
#  'types/fractional': 0,
#  'types/boolean': 0,
#  'types/string': 1,
#  'types/object': 0,
#  'types/tensor': 0,
#  'distribution/mean': 0.0,
#  'distribution/stddev': 0.0,
#  'distribution/n': 0,
#  'distribution/max': nan,
#  'distribution/min': nan,
#  'distribution/q_01': None,
#  'distribution/q_05': None,
#  'distribution/q_10': None,
#  'distribution/q_25': None,
#  'distribution/median': None,
#  'distribution/q_75': None,
#  'distribution/q_90': None,
#  'distribution/q_95': None,
#  'distribution/q_99': None,
#  'cardinality/est': 1.0,
#  'cardinality/upper_1': 1.000049929250618,
#  'cardinality/lower_1': 1.0}

# %%
results.view().to_pandas()
# Out:
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                            1.0                  1.0
# prompt.aggregate_reading_level                    1.0                  1.0
# prompt.automated_readability_index                1.0                  1.0
# prompt.character_count                            1.0                  1.0
# prompt.difficult_words                            1.0                  1.0
# prompt.flesch_reading_ease                        1.0                  1.0
# prompt.has_patterns                               NaN                  NaN
# prompt.letter_count                               1.0                  1.0
# prompt.lexicon_count                              1.0                  1.0
# prompt.monosyllable_count                         1.0                  1.0
# prompt.polysyllable_count                         1.0                  1.0
# prompt.sentence_count                             1.0                  1.0
# prompt.syllable_count                             1.0                  1.0
# response                                          1.0                  1.0
# response.aggregate_reading_level                  1.0                  1.0
# response.automated_readability_index              1.0                  1.0
# response.character_count                          1.0                  1.0
# response.difficult_words                          1.0                  1.0
# response.flesch_reading_ease                      1.0                  1.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             1.0                  1.0
# response.lexicon_count                            1.0                  1.0
# response.monosyllable_count                       1.0                  1.0
# response.polysyllable_count                       1.0                  1.0
# response.sentence_count                           1.0                  1.0
# response.syllable_count                           1.0                  1.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                            1.00005           0
# prompt.aggregate_reading_level                    1.00005           0
# prompt.automated_readability_index                1.00005           0
# prompt.character_count                            1.00005           0
# prompt.difficult_words                            1.00005           0
# prompt.flesch_reading_ease                        1.00005           0
# prompt.has_patterns                                   NaN           0
# prompt.letter_count                               1.00005           0
# prompt.lexicon_count                              1.00005           0
# prompt.monosyllable_count                         1.00005           0
# prompt.polysyllable_count                         1.00005           0
# prompt.sentence_count                             1.00005           0
# prompt.syllable_count                             1.00005           0
# response                                          1.00005           0
# response.aggregate_reading_level                  1.00005           0
# response.automated_readability_index              1.00005           0
# response.character_count                          1.00005           0
# response.difficult_words                          1.00005           0
# response.flesch_reading_ease                      1.00005           0
# response.has_patterns                                 NaN           0
# response.letter_count                             1.00005           0
# response.lexicon_count                            1.00005           0
# response.monosyllable_count                       1.00005           0
# response.polysyllable_count                       1.00005           0
# response.sentence_count                           1.00005           0
# response.syllable_count                           1.00005           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                       1           0            0
# prompt.aggregate_reading_level               1           0            0
# prompt.automated_readability_index           1           0            0
# prompt.character_count                       1           0            0
# prompt.difficult_words                       1           0            0
# prompt.flesch_reading_ease                   1           0            0
# prompt.has_patterns                          1           0            1
# prompt.letter_count                          1           0            0
# prompt.lexicon_count                         1           0            0
# prompt.monosyllable_count                    1           0            0
# prompt.polysyllable_count                    1           0            0
# prompt.sentence_count                        1           0            0
# prompt.syllable_count                        1           0            0
# response                                     1           0            0
# response.aggregate_reading_level             1           0            0
# response.automated_readability_index         1           0            0
# response.character_count                     1           0            0
# response.difficult_words                     1           0            0
# response.flesch_reading_ease                 1           0            0
# response.has_patterns                        1           0            1
# response.letter_count                        1           0            0
# response.lexicon_count                       1           0            0
# response.monosyllable_count                  1           0            0
# response.polysyllable_count                  1           0            0
# response.sentence_count                      1           0            0
# response.syllable_count                      1           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN               0.00
# prompt.aggregate_reading_level                    0.00               0.00
# prompt.automated_readability_index                7.30               7.30
# prompt.character_count                            6.00               6.00
# prompt.difficult_words                            0.00               0.00
# prompt.flesch_reading_ease                       36.62              36.62
# prompt.has_patterns                                NaN                NaN
# prompt.letter_count                               5.00               5.00
# prompt.lexicon_count                              1.00               1.00
# prompt.monosyllable_count                         0.00               0.00
# prompt.polysyllable_count                         0.00               0.00
# prompt.sentence_count                             1.00               1.00
# prompt.syllable_count                             2.00               2.00
# response                                           NaN               0.00
# response.aggregate_reading_level                  0.00               0.00
# response.automated_readability_index              7.30               7.30
# response.character_count                          6.00               6.00
# response.difficult_words                          0.00               0.00
# response.flesch_reading_ease                    121.22             121.22
# response.has_patterns                              NaN                NaN
# response.letter_count                             5.00               5.00
# response.lexicon_count                            1.00               1.00
# response.monosyllable_count                       1.00               1.00
# response.polysyllable_count                       0.00               0.00
# response.sentence_count                           1.00               1.00
# response.syllable_count                           1.00               1.00
#
#                                       distribution/median  ...  \
# column                                                     ...
# prompt                                                NaN  ...
# prompt.aggregate_reading_level                       0.00  ...
# prompt.automated_readability_index                   7.30  ...
# prompt.character_count                               6.00  ...
# prompt.difficult_words                               0.00  ...
# prompt.flesch_reading_ease                          36.62  ...
# prompt.has_patterns                                   NaN  ...
# prompt.letter_count                                  5.00  ...
# prompt.lexicon_count                                 1.00  ...
# prompt.monosyllable_count                            0.00  ...
# prompt.polysyllable_count                            0.00  ...
# prompt.sentence_count                                1.00  ...
# prompt.syllable_count                                2.00  ...
# response                                              NaN  ...
# response.aggregate_reading_level                     0.00  ...
# response.automated_readability_index                 7.30  ...
# response.character_count                             6.00  ...
# response.difficult_words                             0.00  ...
# response.flesch_reading_ease                       121.22  ...
# response.has_patterns                                 NaN  ...
# response.letter_count                                5.00  ...
# response.lexicon_count                               1.00  ...
# response.monosyllable_count                          1.00  ...
# response.polysyllable_count                          0.00  ...
# response.sentence_count                              1.00  ...
# response.syllable_count                              1.00  ...
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                       1               0
# prompt.automated_readability_index                   1               0
# prompt.character_count                               0               1
# prompt.difficult_words                               0               1
# prompt.flesch_reading_ease                           1               0
# prompt.has_patterns                                  0               0
# prompt.letter_count                                  0               1
# prompt.lexicon_count                                 0               1
# prompt.monosyllable_count                            0               1
# prompt.polysyllable_count                            0               1
# prompt.sentence_count                                0               1
# prompt.syllable_count                                0               1
# response                                             0               0
# response.aggregate_reading_level                     1               0
# response.automated_readability_index                 1               0
# response.character_count                             0               1
# response.difficult_words                             0               1
# response.flesch_reading_ease                         1               0
# response.has_patterns                                0               0
# response.letter_count                                0               1
# response.lexicon_count                               0               1
# response.monosyllable_count                          0               1
# response.polysyllable_count                          0               1
# response.sentence_count                              0               1
# response.syllable_count                              0               1
#
#                                       types/object  types/string  \
# column
# prompt                                           0             1
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.syllable_count                            0             0
# response                                         0             1
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             0
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.sentence_count                          0             0
# response.syllable_count                          0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0       6.0       6.0
# prompt.difficult_words                           0       0.0       0.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.letter_count                              0       5.0       5.0
# prompt.lexicon_count                             0       1.0       1.0
# prompt.monosyllable_count                        0       0.0       0.0
# prompt.polysyllable_count                        0       0.0       0.0
# prompt.sentence_count                            0       1.0       1.0
# prompt.syllable_count                            0       2.0       2.0
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0       6.0       6.0
# response.difficult_words                         0       0.0       0.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0       5.0       5.0
# response.lexicon_count                           0       1.0       1.0
# response.monosyllable_count                      0       1.0       1.0
# response.polysyllable_count                      0       0.0       0.0
# response.sentence_count                          0       1.0       1.0
# response.syllable_count                          0       1.0       1.0
#
#                                       frequent_items/frequent_strings
# column
# prompt                                                            NaN
# prompt.aggregate_reading_level                                    NaN
# prompt.automated_readability_index                                NaN
# prompt.character_count                                            NaN
# prompt.difficult_words                                            NaN
# prompt.flesch_reading_ease                                        NaN
# prompt.has_patterns                                                []
# prompt.letter_count                                               NaN
# prompt.lexicon_count                                              NaN
# prompt.monosyllable_count                                         NaN
# prompt.polysyllable_count                                         NaN
# prompt.sentence_count                                             NaN
# prompt.syllable_count                                             NaN
# response                                                          NaN
# response.aggregate_reading_level                                  NaN
# response.automated_readability_index                              NaN
# response.character_count                                          NaN
# response.difficult_words                                          NaN
# response.flesch_reading_ease                                      NaN
# response.has_patterns                                              []
# response.letter_count                                             NaN
# response.lexicon_count                                            NaN
# response.monosyllable_count                                       NaN
# response.polysyllable_count                                       NaN
# response.sentence_count                                           NaN
# response.syllable_count                                           NaN
#
# [26 rows x 31 columns]

# %%
results_profile = results.profile()

# %%
type(results_profile)
# Out:
# whylogs.core.dataset_profile.DatasetProfile

# %% [markdown]
# The object is a dataset profile represents a collection of in-memory profiling stats for a dataset. The [track method](https://whylogs.readthedocs.io/en/latest/api/whylogs/core/dataset_profile/index.html#whylogs.core.dataset_profile.DatasetProfile.track) updates the inmemory data set and calcuate the metric, but does not upload it to the Dashbaord.

# %%
results_profile.track({"prompt": "What is your number?","response": "my phone is +1 309-404-7587"})

# %%
results_profile.view().to_pandas()
# Out:
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                            2.0                  2.0
# prompt.aggregate_reading_level                    2.0                  2.0
# prompt.automated_readability_index                2.0                  2.0
# prompt.character_count                            2.0                  2.0
# prompt.difficult_words                            1.0                  1.0
# prompt.flesch_reading_ease                        2.0                  2.0
# prompt.has_patterns                               NaN                  NaN
# prompt.letter_count                               2.0                  2.0
# prompt.lexicon_count                              2.0                  2.0
# prompt.monosyllable_count                         2.0                  2.0
# prompt.polysyllable_count                         1.0                  1.0
# prompt.sentence_count                             1.0                  1.0
# prompt.syllable_count                             2.0                  2.0
# response                                          2.0                  2.0
# response.aggregate_reading_level                  2.0                  2.0
# response.automated_readability_index              2.0                  2.0
# response.character_count                          2.0                  2.0
# response.difficult_words                          1.0                  1.0
# response.flesch_reading_ease                      2.0                  2.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             2.0                  2.0
# response.lexicon_count                            2.0                  2.0
# response.monosyllable_count                       2.0                  2.0
# response.polysyllable_count                       1.0                  1.0
# response.sentence_count                           1.0                  1.0
# response.syllable_count                           2.0                  2.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                            2.00010           0
# prompt.aggregate_reading_level                    2.00010           0
# prompt.automated_readability_index                2.00010           0
# prompt.character_count                            2.00010           0
# prompt.difficult_words                            1.00005           0
# prompt.flesch_reading_ease                        2.00010           0
# prompt.has_patterns                                   NaN           0
# prompt.letter_count                               2.00010           0
# prompt.lexicon_count                              2.00010           0
# prompt.monosyllable_count                         2.00010           0
# prompt.polysyllable_count                         1.00005           0
# prompt.sentence_count                             1.00005           0
# prompt.syllable_count                             2.00010           0
# response                                          2.00010           0
# response.aggregate_reading_level                  2.00010           0
# response.automated_readability_index              2.00010           0
# response.character_count                          2.00010           0
# response.difficult_words                          1.00005           0
# response.flesch_reading_ease                      2.00010           0
# response.has_patterns                                 NaN           0
# response.letter_count                             2.00010           0
# response.lexicon_count                            2.00010           0
# response.monosyllable_count                       2.00010           0
# response.polysyllable_count                       1.00005           0
# response.sentence_count                           1.00005           0
# response.syllable_count                           2.00010           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                       2           0            0
# prompt.aggregate_reading_level               2           0            0
# prompt.automated_readability_index           2           0            0
# prompt.character_count                       2           0            0
# prompt.difficult_words                       2           0            0
# prompt.flesch_reading_ease                   2           0            0
# prompt.has_patterns                          2           0            2
# prompt.letter_count                          2           0            0
# prompt.lexicon_count                         2           0            0
# prompt.monosyllable_count                    2           0            0
# prompt.polysyllable_count                    2           0            0
# prompt.sentence_count                        2           0            0
# prompt.syllable_count                        2           0            0
# response                                     2           0            0
# response.aggregate_reading_level             2           0            0
# response.automated_readability_index         2           0            0
# response.character_count                     2           0            0
# response.difficult_words                     2           0            0
# response.flesch_reading_ease                 2           0            0
# response.has_patterns                        2           0            1
# response.letter_count                        2           0            0
# response.lexicon_count                       2           0            0
# response.monosyllable_count                  2           0            0
# response.polysyllable_count                  2           0            0
# response.sentence_count                      2           0            0
# response.syllable_count                      2           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN               0.00
# prompt.aggregate_reading_level                    1.00               0.50
# prompt.automated_readability_index                7.30               3.95
# prompt.character_count                           17.00              11.50
# prompt.difficult_words                            0.00               0.00
# prompt.flesch_reading_ease                       92.80              64.71
# prompt.has_patterns                                NaN                NaN
# prompt.letter_count                              16.00              10.50
# prompt.lexicon_count                              4.00               2.50
# prompt.monosyllable_count                         3.00               1.50
# prompt.polysyllable_count                         0.00               0.00
# prompt.sentence_count                             1.00               1.00
# prompt.syllable_count                             5.00               3.50
# response                                           NaN               0.00
# response.aggregate_reading_level                  2.00               1.00
# response.automated_readability_index              7.30               5.00
# response.character_count                         23.00              14.50
# response.difficult_words                          0.00               0.00
# response.flesch_reading_ease                    121.22             119.19
# response.has_patterns                              NaN                NaN
# response.letter_count                            20.00              12.50
# response.lexicon_count                            5.00               3.00
# response.monosyllable_count                       5.00               3.00
# response.polysyllable_count                       0.00               0.00
# response.sentence_count                           1.00               1.00
# response.syllable_count                           5.00               3.00
#
#                                       distribution/median  ...  \
# column                                                     ...
# prompt                                                NaN  ...
# prompt.aggregate_reading_level                       1.00  ...
# prompt.automated_readability_index                   7.30  ...
# prompt.character_count                              17.00  ...
# prompt.difficult_words                               0.00  ...
# prompt.flesch_reading_ease                          92.80  ...
# prompt.has_patterns                                   NaN  ...
# prompt.letter_count                                 16.00  ...
# prompt.lexicon_count                                 4.00  ...
# prompt.monosyllable_count                            3.00  ...
# prompt.polysyllable_count                            0.00  ...
# prompt.sentence_count                                1.00  ...
# prompt.syllable_count                                5.00  ...
# response                                              NaN  ...
# response.aggregate_reading_level                     2.00  ...
# response.automated_readability_index                 7.30  ...
# response.character_count                            23.00  ...
# response.difficult_words                             0.00  ...
# response.flesch_reading_ease                       121.22  ...
# response.has_patterns                                 NaN  ...
# response.letter_count                               20.00  ...
# response.lexicon_count                               5.00  ...
# response.monosyllable_count                          5.00  ...
# response.polysyllable_count                          0.00  ...
# response.sentence_count                              1.00  ...
# response.syllable_count                              5.00  ...
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                       2               0
# prompt.automated_readability_index                   2               0
# prompt.character_count                               0               2
# prompt.difficult_words                               0               2
# prompt.flesch_reading_ease                           2               0
# prompt.has_patterns                                  0               0
# prompt.letter_count                                  0               2
# prompt.lexicon_count                                 0               2
# prompt.monosyllable_count                            0               2
# prompt.polysyllable_count                            0               2
# prompt.sentence_count                                0               2
# prompt.syllable_count                                0               2
# response                                             0               0
# response.aggregate_reading_level                     2               0
# response.automated_readability_index                 2               0
# response.character_count                             0               2
# response.difficult_words                             0               2
# response.flesch_reading_ease                         2               0
# response.has_patterns                                0               0
# response.letter_count                                0               2
# response.lexicon_count                               0               2
# response.monosyllable_count                          0               2
# response.polysyllable_count                          0               2
# response.sentence_count                              0               2
# response.syllable_count                              0               2
#
#                                       types/object  types/string  \
# column
# prompt                                           0             2
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.syllable_count                            0             0
# response                                         0             2
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             1
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.sentence_count                          0             0
# response.syllable_count                          0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0      17.0       6.0
# prompt.difficult_words                           0       0.0       0.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.letter_count                              0      16.0       5.0
# prompt.lexicon_count                             0       4.0       1.0
# prompt.monosyllable_count                        0       3.0       0.0
# prompt.polysyllable_count                        0       0.0       0.0
# prompt.sentence_count                            0       1.0       1.0
# prompt.syllable_count                            0       5.0       2.0
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0      23.0       6.0
# response.difficult_words                         0       0.0       0.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0      20.0       5.0
# response.lexicon_count                           0       5.0       1.0
# response.monosyllable_count                      0       5.0       1.0
# response.polysyllable_count                      0       0.0       0.0
# response.sentence_count                          0       1.0       1.0
# response.syllable_count                          0       5.0       1.0
#
#                                                         frequent_items/frequent_strings
# column
# prompt                                                                              NaN
# prompt.aggregate_reading_level                                                      NaN
# prompt.automated_readability_index                                                  NaN
# prompt.character_count                                                              NaN
# prompt.difficult_words                                                              NaN
# prompt.flesch_reading_ease                                                          NaN
# prompt.has_patterns                                                                  []
# prompt.letter_count                                                                 NaN
# prompt.lexicon_count                                                                NaN
# prompt.monosyllable_count                                                           NaN
# prompt.polysyllable_count                                                           NaN
# prompt.sentence_count                                                               NaN
# prompt.syllable_count                                                               NaN
# response                                                                            NaN
# response.aggregate_reading_level                                                    NaN
# response.automated_readability_index                                                NaN
# response.character_count                                                            NaN
# response.difficult_words                                                            NaN
# response.flesch_reading_ease                                                        NaN
# response.has_patterns                 [FrequentItem(value='phone number', est=1, upp...
# response.letter_count                                                               NaN
# response.lexicon_count                                                              NaN
# response.monosyllable_count                                                         NaN
# response.polysyllable_count                                                         NaN
# response.sentence_count                                                             NaN
# response.syllable_count                                                             NaN
#
# [26 rows x 31 columns]
