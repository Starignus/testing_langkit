# %% [markdown]
# <a href="https://colab.research.google.com/github/Starignus/testing_langkit/blob/main/00_Intro_to_LLM_Monitoring_LangKit_and_WhyLabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Monitoring Large Language Models (LLMs) with LangKit
#
# In this example we'll show how to generate out-of-the-box text metrics for Hugging Face LLMs using LangKit and monitor them in the WhyLabs Observability Platform.
#
# [Video Youtube](https://www.youtube.com/watch?v=DLJ8m3wMJrs)
#
# LangKit can extract relevant signals from unstructured text data, such as:
#
# - [Text Quality](https://github.com/whylabs/langkit/blob/main/langkit/docs/features/quality.md)
# - [Text Relevance](https://github.com/whylabs/langkit/blob/main/langkit/docs/features/relevance.md)
# - [Security and Privacy](https://github.com/whylabs/langkit/blob/main/langkit/docs/features/security.md)
# - [Sentiment and Toxicity](https://github.com/whylabs/langkit/blob/main/langkit/docs/features/sentiment.md)
#
# For this example, we'll use the GPT2 model since it's lightweight and easy to run without a GPU, but the example can be run any of the larger Hugging Face models.
#
# ![](https://github.com/whylabs/langkit/blob/main/static/img/LangKit_graphic.png?raw=true)
#
#
# ## Setup
#
# To run this notebook
# - Google Account `file > save a copy in drive`
# - [Free WhyLabs Account](https://whylabs.ai/free)
#
# Other useful links:
# - LangKit [GitHub](https://github.com/whylabs/langkit)
# - whylogs [GitHub](https://github.com/whylabs/whylogs/)
# - [Slack channel](https://bit.ly/r2ai-slack) (Ask questions after the workshop here)

# %%
# Run code cells by pressing the play button
# or hitting Shift+Enter when highlighted
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Install Hugging Face Transformers & LangKit

# %%
# %pip install transformers
# %pip install 'langkit[all]'
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: langkit[all] in /usr/local/lib/python3.10/dist-packages (0.0.30)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.5.3)
# Requirement already satisfied: textstat<0.8.0,>=0.7.3 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (0.7.3)
# Requirement already satisfied: whylogs<2.0.0,>=1.3.19 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.3.24)
# Requirement already satisfied: datasets<3.0.0,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.17.1)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (0.4.1)
# Requirement already satisfied: h5py<4.0.0,>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (3.10.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.1.1 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (8.1.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.25.2)
# Requirement already satisfied: openai<2.0.0,>=0.27.6 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (1.12.0)
# Requirement already satisfied: presidio-analyzer<3.0.0,>=2.2.351 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.2.353)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.3.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (2.1.0+cu121)
# Requirement already satisfied: vadersentiment<4.0.0,>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from langkit[all]) (3.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate<0.5.0,>=0.4.0->langkit[all]) (0.18.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.10)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->langkit[all]) (2023.12.25)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (2.6.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.27.6->langkit[all]) (4.9.0)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.7.4)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (5.1.1)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (8.13.30)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (4.37.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (1.11.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (0.1.99)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (9.4.0)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat<0.8.0,>=0.7.3->langkit[all]) (0.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->langkit[all]) (2.1.0)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.20.3)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.30.0.0 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (2.31.0.20240218)
# Requirement already satisfied: whylabs-client<0.6.0,>=0.5.10 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (0.5.10)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in /usr/local/lib/python3.10/dist-packages (from whylogs<2.0.0,>=1.3.19->langkit[all]) (3.4.1.dev3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->langkit[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->langkit[all]) (2023.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.12.0->langkit[all]) (4.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=0.27.6->langkit[all]) (0.14.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=0.27.6->langkit[all]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=0.27.6->langkit[all]) (2.16.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->langkit[all]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.12.0->langkit[all]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.12.0->langkit[all]) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (6.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (3.3.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->langkit[all]) (2.1.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->langkit[all]) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->langkit[all]) (1.3.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (2.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.1->langkit[all]) (0.2.13)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio-analyzer<3.0.0,>=2.2.351->langkit[all]) (0.16.0)

# %% [markdown]
# ## 👋 Hello, World! Take a quick look at LangKit metrics
#
# In the below code we log a few example prompt/response pairs and send metrics to WhyLabs.

# %%
from langkit import llm_metrics # alternatively use 'light_metrics'
import whylogs as why

why.init(session_type='whylabs_anonymous')
# Note: llm_metrics.init() downloads models so this is slow first time.
schema = llm_metrics.init()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Initializing session with config /root/.config/whylogs/config.ini
#
# ✅ Using session type: WHYLABS_ANONYMOUS
#  ⤷ session id: session-hSpukmj7

# %%
# !ls ~/.cache/
# Out:
# huggingface  matplotlib  node-gyp  pip

# %%
# !ls /root/nltk_data
# Out:
# sentiment

# %%
from langkit.whylogs.samples import load_chats, show_first_chat

# Let's look at what's in this toy example:
chats = load_chats()
print(f"There are {len(chats)} records in this toy example data, here's the first one:")
show_first_chat(chats)

results = why.log(chats, name="langkit-sample-chats-all", schema=schema)
# Out:
# There are 50 records in this toy example data, here's the first one:
# prompt: Hello, response: World!
#
#
# ✅ Aggregated 50 rows into profile langkit-sample-chats-all
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-1/profiles?profile=ref-xWfyuquKXkAACUSd&sessionToken=session-hSpukmj7

# %% [markdown]
# You can check the dashboard and lagkit allow us to add costume emtrics. Note: Example in the [Behavioural and Monitoring notebook](https://colab.research.google.com/drive/18JaeB0tmWrKjOD86rOzKNpsPyT8TWcBW#scrollTo=b9NZxbcjA85U&uniqifier=3)

# %%
chats.head()
# Out:
#                                               prompt  \
# 0                                             Hello,
# 1                                      Hello, World!
# 2  Aproximately how many atoms are in the known u...
# 3  What is the speed of light in m/s? Can you out...
# 4  How many digits are in a Discover credit card ...
#
#                                             response
# 0                                             World!
# 1                 Hello! How can I assist you today?
# 2  There are approximately 10^80 atoms in the obs...
# 3  The speed of light in a vacuum is approximatel...
# 4  A Discover credit card number has 16 digits. T...

# %% [markdown]
# ##🤗 Use LangKit to monitor LLMs with any Hugging Face model
#
# Import and ititialize the Hugging Face GPT2 model + tokenizer

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# %%
# # Example of loading different models
# from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-70b-chat-hf")
# model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-70b-chat-hf")

# %% [markdown]
# ### Create GPT model function
# This will take in a prompt and return a dictionary containing the model response and prompt.

# %%
def gpt_model(prompt):

  # Encode the prompt
  input_ids = tokenizer.encode(prompt, return_tensors='pt')

  # Generate a response (100 characters, temperature for felixibility)
  output = model.generate(input_ids, max_length=100, temperature=0.8,
                          do_sample=True, pad_token_id=tokenizer.eos_token_id)

  # Decode the output
  response = tokenizer.decode(output[0], skip_special_tokens=True)

  # Combine the prompt and the output into a dictionary
  prompt_and_response = {
      "prompt": prompt,
      "response": response
  }

  # print(response)
  return prompt_and_response

# %%
# Example
prompt_and_response = gpt_model("Tell me a story about a cute dog")
print(prompt_and_response)
# Out:
# {'prompt': 'Tell me a story about a cute dog', 'response': 'Tell me a story about a cute dog that you know you\'d love to have in your home.\n\nThe story begins with a dog named Dolly, that you\'ve heard of and that you\'ve been looking forward to having. Once you get used to the dog\'s personality and its personality is strong, you finally realize that you absolutely need a good partner.\n\n"What do you expect from your best mate, Jeez?"\n\n"I think you\'re lucky with a big heart'}

# %% [markdown]
# ### Create & Inspect Language Metrics with LangKit
#
# LangKit provides a toolkit of metrics for LLM applications, lets initialize them and create a profile of the data that can be viewed in WhyLabs for quick analysis.

# %%
from langkit import llm_metrics # alternatively use 'light_metrics'
import whylogs as why
import pandas as pd

# Set to show all columns in dataframe
pd.set_option("display.max_columns", None)

# Note: llm_metrics.init() downloads models so this is slow first time.
schema = llm_metrics.init()

# %%
# Whylogs to create the statistical profiles of the data
# no name was given with name=
profile = why.log(prompt_and_response, schema=schema).profile()
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-1/profiles?profile=1708473600000&sessionToken=session-hSpukmj7

# %% [markdown]
# We can also see all our values by viewing our LangKit profile in a pandas dataframe.
#
# You can use this data in real-time to make descsion about prompts and reponses, such as setting guardrails on your model.

# %%
profview = profile.view()
profview.to_pandas()
# Out:
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                            1.0                  1.0
# prompt.aggregate_reading_level                    1.0                  1.0
# prompt.automated_readability_index                1.0                  1.0
# prompt.character_count                            1.0                  1.0
# prompt.difficult_words                            1.0                  1.0
# prompt.flesch_reading_ease                        1.0                  1.0
# prompt.has_patterns                               NaN                  NaN
# prompt.jailbreak_similarity                       1.0                  1.0
# prompt.letter_count                               1.0                  1.0
# prompt.lexicon_count                              1.0                  1.0
# prompt.monosyllable_count                         1.0                  1.0
# prompt.polysyllable_count                         1.0                  1.0
# prompt.sentence_count                             1.0                  1.0
# prompt.sentiment_nltk                             1.0                  1.0
# prompt.syllable_count                             1.0                  1.0
# prompt.toxicity                                   1.0                  1.0
# response                                          1.0                  1.0
# response.aggregate_reading_level                  1.0                  1.0
# response.automated_readability_index              1.0                  1.0
# response.character_count                          1.0                  1.0
# response.difficult_words                          1.0                  1.0
# response.flesch_reading_ease                      1.0                  1.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             1.0                  1.0
# response.lexicon_count                            1.0                  1.0
# response.monosyllable_count                       1.0                  1.0
# response.polysyllable_count                       1.0                  1.0
# response.refusal_similarity                       1.0                  1.0
# response.relevance_to_prompt                      1.0                  1.0
# response.sentence_count                           1.0                  1.0
# response.sentiment_nltk                           1.0                  1.0
# response.syllable_count                           1.0                  1.0
# response.toxicity                                 1.0                  1.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                            1.00005           0
# prompt.aggregate_reading_level                    1.00005           0
# prompt.automated_readability_index                1.00005           0
# prompt.character_count                            1.00005           0
# prompt.difficult_words                            1.00005           0
# prompt.flesch_reading_ease                        1.00005           0
# prompt.has_patterns                                   NaN           0
# prompt.jailbreak_similarity                       1.00005           0
# prompt.letter_count                               1.00005           0
# prompt.lexicon_count                              1.00005           0
# prompt.monosyllable_count                         1.00005           0
# prompt.polysyllable_count                         1.00005           0
# prompt.sentence_count                             1.00005           0
# prompt.sentiment_nltk                             1.00005           0
# prompt.syllable_count                             1.00005           0
# prompt.toxicity                                   1.00005           0
# response                                          1.00005           0
# response.aggregate_reading_level                  1.00005           0
# response.automated_readability_index              1.00005           0
# response.character_count                          1.00005           0
# response.difficult_words                          1.00005           0
# response.flesch_reading_ease                      1.00005           0
# response.has_patterns                                 NaN           0
# response.letter_count                             1.00005           0
# response.lexicon_count                            1.00005           0
# response.monosyllable_count                       1.00005           0
# response.polysyllable_count                       1.00005           0
# response.refusal_similarity                       1.00005           0
# response.relevance_to_prompt                      1.00005           0
# response.sentence_count                           1.00005           0
# response.sentiment_nltk                           1.00005           0
# response.syllable_count                           1.00005           0
# response.toxicity                                 1.00005           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                       1           0            0
# prompt.aggregate_reading_level               1           0            0
# prompt.automated_readability_index           1           0            0
# prompt.character_count                       1           0            0
# prompt.difficult_words                       1           0            0
# prompt.flesch_reading_ease                   1           0            0
# prompt.has_patterns                          1           0            1
# prompt.jailbreak_similarity                  1           0            0
# prompt.letter_count                          1           0            0
# prompt.lexicon_count                         1           0            0
# prompt.monosyllable_count                    1           0            0
# prompt.polysyllable_count                    1           0            0
# prompt.sentence_count                        1           0            0
# prompt.sentiment_nltk                        1           0            0
# prompt.syllable_count                        1           0            0
# prompt.toxicity                              1           0            0
# response                                     1           0            0
# response.aggregate_reading_level             1           0            0
# response.automated_readability_index         1           0            0
# response.character_count                     1           0            0
# response.difficult_words                     1           0            0
# response.flesch_reading_ease                 1           0            0
# response.has_patterns                        1           0            1
# response.letter_count                        1           0            0
# response.lexicon_count                       1           0            0
# response.monosyllable_count                  1           0            0
# response.polysyllable_count                  1           0            0
# response.refusal_similarity                  1           0            0
# response.relevance_to_prompt                 1           0            0
# response.sentence_count                      1           0            0
# response.sentiment_nltk                      1           0            0
# response.syllable_count                      1           0            0
# response.toxicity                            1           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN           0.000000
# prompt.aggregate_reading_level                1.000000           1.000000
# prompt.automated_readability_index           -2.800000          -2.800000
# prompt.character_count                       25.000000          25.000000
# prompt.difficult_words                        0.000000           0.000000
# prompt.flesch_reading_ease                  105.660000         105.660000
# prompt.has_patterns                                NaN                NaN
# prompt.jailbreak_similarity                   0.143321           0.143321
# prompt.letter_count                          25.000000          25.000000
# prompt.lexicon_count                          8.000000           8.000000
# prompt.monosyllable_count                     7.000000           7.000000
# prompt.polysyllable_count                     0.000000           0.000000
# prompt.sentence_count                         1.000000           1.000000
# prompt.sentiment_nltk                         0.458800           0.458800
# prompt.syllable_count                         9.000000           9.000000
# prompt.toxicity                               0.005245           0.005245
# response                                           NaN           0.000000
# response.aggregate_reading_level              6.000000           6.000000
# response.automated_readability_index          6.500000           6.500000
# response.character_count                    334.000000         334.000000
# response.difficult_words                      5.000000           5.000000
# response.flesch_reading_ease                 81.020000          81.020000
# response.has_patterns                              NaN                NaN
# response.letter_count                       319.000000         319.000000
# response.lexicon_count                       78.000000          78.000000
# response.monosyllable_count                  62.000000          62.000000
# response.polysyllable_count                   5.000000           5.000000
# response.refusal_similarity                   0.061935           0.061935
# response.relevance_to_prompt                  0.724536           0.724536
# response.sentence_count                       5.000000           5.000000
# response.sentiment_nltk                       0.966900           0.966900
# response.syllable_count                     104.000000         104.000000
# response.toxicity                             0.004596           0.004596
#
#                                       distribution/median  distribution/min  \
# column
# prompt                                                NaN               NaN
# prompt.aggregate_reading_level                   1.000000          1.000000
# prompt.automated_readability_index              -2.800000         -2.800000
# prompt.character_count                          25.000000         25.000000
# prompt.difficult_words                           0.000000          0.000000
# prompt.flesch_reading_ease                     105.660000        105.660000
# prompt.has_patterns                                   NaN               NaN
# prompt.jailbreak_similarity                      0.143321          0.143321
# prompt.letter_count                             25.000000         25.000000
# prompt.lexicon_count                             8.000000          8.000000
# prompt.monosyllable_count                        7.000000          7.000000
# prompt.polysyllable_count                        0.000000          0.000000
# prompt.sentence_count                            1.000000          1.000000
# prompt.sentiment_nltk                            0.458800          0.458800
# prompt.syllable_count                            9.000000          9.000000
# prompt.toxicity                                  0.005245          0.005245
# response                                              NaN               NaN
# response.aggregate_reading_level                 6.000000          6.000000
# response.automated_readability_index             6.500000          6.500000
# response.character_count                       334.000000        334.000000
# response.difficult_words                         5.000000          5.000000
# response.flesch_reading_ease                    81.020000         81.020000
# response.has_patterns                                 NaN               NaN
# response.letter_count                          319.000000        319.000000
# response.lexicon_count                          78.000000         78.000000
# response.monosyllable_count                     62.000000         62.000000
# response.polysyllable_count                      5.000000          5.000000
# response.refusal_similarity                      0.061935          0.061935
# response.relevance_to_prompt                     0.724536          0.724536
# response.sentence_count                          5.000000          5.000000
# response.sentiment_nltk                          0.966900          0.966900
# response.syllable_count                        104.000000        104.000000
# response.toxicity                                0.004596          0.004596
#
#                                       distribution/n  distribution/q_01  \
# column
# prompt                                           0.0                NaN
# prompt.aggregate_reading_level                   1.0           1.000000
# prompt.automated_readability_index               1.0          -2.800000
# prompt.character_count                           1.0          25.000000
# prompt.difficult_words                           1.0           0.000000
# prompt.flesch_reading_ease                       1.0         105.660000
# prompt.has_patterns                              NaN                NaN
# prompt.jailbreak_similarity                      1.0           0.143321
# prompt.letter_count                              1.0          25.000000
# prompt.lexicon_count                             1.0           8.000000
# prompt.monosyllable_count                        1.0           7.000000
# prompt.polysyllable_count                        1.0           0.000000
# prompt.sentence_count                            1.0           1.000000
# prompt.sentiment_nltk                            1.0           0.458800
# prompt.syllable_count                            1.0           9.000000
# prompt.toxicity                                  1.0           0.005245
# response                                         0.0                NaN
# response.aggregate_reading_level                 1.0           6.000000
# response.automated_readability_index             1.0           6.500000
# response.character_count                         1.0         334.000000
# response.difficult_words                         1.0           5.000000
# response.flesch_reading_ease                     1.0          81.020000
# response.has_patterns                            NaN                NaN
# response.letter_count                            1.0         319.000000
# response.lexicon_count                           1.0          78.000000
# response.monosyllable_count                      1.0          62.000000
# response.polysyllable_count                      1.0           5.000000
# response.refusal_similarity                      1.0           0.061935
# response.relevance_to_prompt                     1.0           0.724536
# response.sentence_count                          1.0           5.000000
# response.sentiment_nltk                          1.0           0.966900
# response.syllable_count                          1.0         104.000000
# response.toxicity                                1.0           0.004596
#
#                                       distribution/q_05  distribution/q_10  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 1.000000           1.000000
# prompt.automated_readability_index            -2.800000          -2.800000
# prompt.character_count                        25.000000          25.000000
# prompt.difficult_words                         0.000000           0.000000
# prompt.flesch_reading_ease                   105.660000         105.660000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.143321           0.143321
# prompt.letter_count                           25.000000          25.000000
# prompt.lexicon_count                           8.000000           8.000000
# prompt.monosyllable_count                      7.000000           7.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                          0.458800           0.458800
# prompt.syllable_count                          9.000000           9.000000
# prompt.toxicity                                0.005245           0.005245
# response                                            NaN                NaN
# response.aggregate_reading_level               6.000000           6.000000
# response.automated_readability_index           6.500000           6.500000
# response.character_count                     334.000000         334.000000
# response.difficult_words                       5.000000           5.000000
# response.flesch_reading_ease                  81.020000          81.020000
# response.has_patterns                               NaN                NaN
# response.letter_count                        319.000000         319.000000
# response.lexicon_count                        78.000000          78.000000
# response.monosyllable_count                   62.000000          62.000000
# response.polysyllable_count                    5.000000           5.000000
# response.refusal_similarity                    0.061935           0.061935
# response.relevance_to_prompt                   0.724536           0.724536
# response.sentence_count                        5.000000           5.000000
# response.sentiment_nltk                        0.966900           0.966900
# response.syllable_count                      104.000000         104.000000
# response.toxicity                              0.004596           0.004596
#
#                                       distribution/q_25  distribution/q_75  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 1.000000           1.000000
# prompt.automated_readability_index            -2.800000          -2.800000
# prompt.character_count                        25.000000          25.000000
# prompt.difficult_words                         0.000000           0.000000
# prompt.flesch_reading_ease                   105.660000         105.660000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.143321           0.143321
# prompt.letter_count                           25.000000          25.000000
# prompt.lexicon_count                           8.000000           8.000000
# prompt.monosyllable_count                      7.000000           7.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                          0.458800           0.458800
# prompt.syllable_count                          9.000000           9.000000
# prompt.toxicity                                0.005245           0.005245
# response                                            NaN                NaN
# response.aggregate_reading_level               6.000000           6.000000
# response.automated_readability_index           6.500000           6.500000
# response.character_count                     334.000000         334.000000
# response.difficult_words                       5.000000           5.000000
# response.flesch_reading_ease                  81.020000          81.020000
# response.has_patterns                               NaN                NaN
# response.letter_count                        319.000000         319.000000
# response.lexicon_count                        78.000000          78.000000
# response.monosyllable_count                   62.000000          62.000000
# response.polysyllable_count                    5.000000           5.000000
# response.refusal_similarity                    0.061935           0.061935
# response.relevance_to_prompt                   0.724536           0.724536
# response.sentence_count                        5.000000           5.000000
# response.sentiment_nltk                        0.966900           0.966900
# response.syllable_count                      104.000000         104.000000
# response.toxicity                              0.004596           0.004596
#
#                                       distribution/q_90  distribution/q_95  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 1.000000           1.000000
# prompt.automated_readability_index            -2.800000          -2.800000
# prompt.character_count                        25.000000          25.000000
# prompt.difficult_words                         0.000000           0.000000
# prompt.flesch_reading_ease                   105.660000         105.660000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.143321           0.143321
# prompt.letter_count                           25.000000          25.000000
# prompt.lexicon_count                           8.000000           8.000000
# prompt.monosyllable_count                      7.000000           7.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                          0.458800           0.458800
# prompt.syllable_count                          9.000000           9.000000
# prompt.toxicity                                0.005245           0.005245
# response                                            NaN                NaN
# response.aggregate_reading_level               6.000000           6.000000
# response.automated_readability_index           6.500000           6.500000
# response.character_count                     334.000000         334.000000
# response.difficult_words                       5.000000           5.000000
# response.flesch_reading_ease                  81.020000          81.020000
# response.has_patterns                               NaN                NaN
# response.letter_count                        319.000000         319.000000
# response.lexicon_count                        78.000000          78.000000
# response.monosyllable_count                   62.000000          62.000000
# response.polysyllable_count                    5.000000           5.000000
# response.refusal_similarity                    0.061935           0.061935
# response.relevance_to_prompt                   0.724536           0.724536
# response.sentence_count                        5.000000           5.000000
# response.sentiment_nltk                        0.966900           0.966900
# response.syllable_count                      104.000000         104.000000
# response.toxicity                              0.004596           0.004596
#
#                                       distribution/q_99  distribution/stddev  \
# column
# prompt                                              NaN                  0.0
# prompt.aggregate_reading_level                 1.000000                  0.0
# prompt.automated_readability_index            -2.800000                  0.0
# prompt.character_count                        25.000000                  0.0
# prompt.difficult_words                         0.000000                  0.0
# prompt.flesch_reading_ease                   105.660000                  0.0
# prompt.has_patterns                                 NaN                  NaN
# prompt.jailbreak_similarity                    0.143321                  0.0
# prompt.letter_count                           25.000000                  0.0
# prompt.lexicon_count                           8.000000                  0.0
# prompt.monosyllable_count                      7.000000                  0.0
# prompt.polysyllable_count                      0.000000                  0.0
# prompt.sentence_count                          1.000000                  0.0
# prompt.sentiment_nltk                          0.458800                  0.0
# prompt.syllable_count                          9.000000                  0.0
# prompt.toxicity                                0.005245                  0.0
# response                                            NaN                  0.0
# response.aggregate_reading_level               6.000000                  0.0
# response.automated_readability_index           6.500000                  0.0
# response.character_count                     334.000000                  0.0
# response.difficult_words                       5.000000                  0.0
# response.flesch_reading_ease                  81.020000                  0.0
# response.has_patterns                               NaN                  NaN
# response.letter_count                        319.000000                  0.0
# response.lexicon_count                        78.000000                  0.0
# response.monosyllable_count                   62.000000                  0.0
# response.polysyllable_count                    5.000000                  0.0
# response.refusal_similarity                    0.061935                  0.0
# response.relevance_to_prompt                   0.724536                  0.0
# response.sentence_count                        5.000000                  0.0
# response.sentiment_nltk                        0.966900                  0.0
# response.syllable_count                      104.000000                  0.0
# response.toxicity                              0.004596                  0.0
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.jailbreak_similarity           SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.sentiment_nltk                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# prompt.toxicity                       SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.refusal_similarity           SummaryType.COLUMN              0
# response.relevance_to_prompt          SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.sentiment_nltk               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
# response.toxicity                     SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                       1               0
# prompt.automated_readability_index                   1               0
# prompt.character_count                               0               1
# prompt.difficult_words                               0               1
# prompt.flesch_reading_ease                           1               0
# prompt.has_patterns                                  0               0
# prompt.jailbreak_similarity                          1               0
# prompt.letter_count                                  0               1
# prompt.lexicon_count                                 0               1
# prompt.monosyllable_count                            0               1
# prompt.polysyllable_count                            0               1
# prompt.sentence_count                                0               1
# prompt.sentiment_nltk                                1               0
# prompt.syllable_count                                0               1
# prompt.toxicity                                      1               0
# response                                             0               0
# response.aggregate_reading_level                     1               0
# response.automated_readability_index                 1               0
# response.character_count                             0               1
# response.difficult_words                             0               1
# response.flesch_reading_ease                         1               0
# response.has_patterns                                0               0
# response.letter_count                                0               1
# response.lexicon_count                               0               1
# response.monosyllable_count                          0               1
# response.polysyllable_count                          0               1
# response.refusal_similarity                          1               0
# response.relevance_to_prompt                         1               0
# response.sentence_count                              0               1
# response.sentiment_nltk                              1               0
# response.syllable_count                              0               1
# response.toxicity                                    1               0
#
#                                       types/object  types/string  \
# column
# prompt                                           0             1
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            0             0
# prompt.toxicity                                  0             0
# response                                         0             1
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             0
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.refusal_similarity                      0             0
# response.relevance_to_prompt                     0             0
# response.sentence_count                          0             0
# response.sentiment_nltk                          0             0
# response.syllable_count                          0             0
# response.toxicity                                0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0      25.0      25.0
# prompt.difficult_words                           0       0.0       0.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.jailbreak_similarity                      0       NaN       NaN
# prompt.letter_count                              0      25.0      25.0
# prompt.lexicon_count                             0       8.0       8.0
# prompt.monosyllable_count                        0       7.0       7.0
# prompt.polysyllable_count                        0       0.0       0.0
# prompt.sentence_count                            0       1.0       1.0
# prompt.sentiment_nltk                            0       NaN       NaN
# prompt.syllable_count                            0       9.0       9.0
# prompt.toxicity                                  0       NaN       NaN
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0     334.0     334.0
# response.difficult_words                         0       5.0       5.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0     319.0     319.0
# response.lexicon_count                           0      78.0      78.0
# response.monosyllable_count                      0      62.0      62.0
# response.polysyllable_count                      0       5.0       5.0
# response.refusal_similarity                      0       NaN       NaN
# response.relevance_to_prompt                     0       NaN       NaN
# response.sentence_count                          0       5.0       5.0
# response.sentiment_nltk                          0       NaN       NaN
# response.syllable_count                          0     104.0     104.0
# response.toxicity                                0       NaN       NaN
#
#                                      frequent_items/frequent_strings
# column
# prompt                                                           NaN
# prompt.aggregate_reading_level                                   NaN
# prompt.automated_readability_index                               NaN
# prompt.character_count                                           NaN
# prompt.difficult_words                                           NaN
# prompt.flesch_reading_ease                                       NaN
# prompt.has_patterns                                               []
# prompt.jailbreak_similarity                                      NaN
# prompt.letter_count                                              NaN
# prompt.lexicon_count                                             NaN
# prompt.monosyllable_count                                        NaN
# prompt.polysyllable_count                                        NaN
# prompt.sentence_count                                            NaN
# prompt.sentiment_nltk                                            NaN
# prompt.syllable_count                                            NaN
# prompt.toxicity                                                  NaN
# response                                                         NaN
# response.aggregate_reading_level                                 NaN
# response.automated_readability_index                             NaN
# response.character_count                                         NaN
# response.difficult_words                                         NaN
# response.flesch_reading_ease                                     NaN
# response.has_patterns                                             []
# response.letter_count                                            NaN
# response.lexicon_count                                           NaN
# response.monosyllable_count                                      NaN
# response.polysyllable_count                                      NaN
# response.refusal_similarity                                      NaN
# response.relevance_to_prompt                                     NaN
# response.sentence_count                                          NaN
# response.sentiment_nltk                                          NaN
# response.syllable_count                                          NaN
# response.toxicity                                                NaN

# %%
profview.to_pandas().columns
# Out:
# Index(['cardinality/est', 'cardinality/lower_1', 'cardinality/upper_1',
#        'counts/inf', 'counts/n', 'counts/nan', 'counts/null',
#        'distribution/max', 'distribution/mean', 'distribution/median',
#        'distribution/min', 'distribution/n', 'distribution/q_01',
#        'distribution/q_05', 'distribution/q_10', 'distribution/q_25',
#        'distribution/q_75', 'distribution/q_90', 'distribution/q_95',
#        'distribution/q_99', 'distribution/stddev', 'type', 'types/boolean',
#        'types/fractional', 'types/integral', 'types/object', 'types/string',
#        'types/tensor', 'ints/max', 'ints/min',
#        'frequent_items/frequent_strings'],
#       dtype='object')

# %% [markdown]
# ### Muliple Prompts

# %%
prompts = ["What is AI?",
           "Tell me a joke.",
           "Who won the world series in 2021?"]

# %%
# Skipping uploading profile to WhyLabs because no name was given with name=
for num, prompt in enumerate(prompts):

  prompt_and_response = gpt_model(prompt)

  # initial profile schema on first profile
  if num == 0:
    profile = why.log(prompt_and_response, schema=schema).profile()
  profile.track(prompt_and_response)
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-1/profiles?profile=1708473600000&sessionToken=session-hSpukmj7

# %%
profview = profile.view()
profview.to_pandas()
# Out:
#                                       cardinality/est  cardinality/lower_1  \
# column
# prompt                                            3.0                  3.0
# prompt.aggregate_reading_level                    2.0                  2.0
# prompt.automated_readability_index                3.0                  3.0
# prompt.character_count                            3.0                  3.0
# prompt.difficult_words                            2.0                  2.0
# prompt.flesch_reading_ease                        3.0                  3.0
# prompt.has_patterns                               NaN                  NaN
# prompt.jailbreak_similarity                       3.0                  3.0
# prompt.letter_count                               3.0                  3.0
# prompt.lexicon_count                              3.0                  3.0
# prompt.monosyllable_count                         3.0                  3.0
# prompt.polysyllable_count                         1.0                  1.0
# prompt.sentence_count                             1.0                  1.0
# prompt.sentiment_nltk                             3.0                  3.0
# prompt.syllable_count                             3.0                  3.0
# prompt.toxicity                                   3.0                  3.0
# response                                          3.0                  3.0
# response.aggregate_reading_level                  3.0                  3.0
# response.automated_readability_index              3.0                  3.0
# response.character_count                          3.0                  3.0
# response.difficult_words                          3.0                  3.0
# response.flesch_reading_ease                      3.0                  3.0
# response.has_patterns                             NaN                  NaN
# response.letter_count                             3.0                  3.0
# response.lexicon_count                            2.0                  2.0
# response.monosyllable_count                       2.0                  2.0
# response.polysyllable_count                       3.0                  3.0
# response.refusal_similarity                       3.0                  3.0
# response.relevance_to_prompt                      3.0                  3.0
# response.sentence_count                           2.0                  2.0
# response.sentiment_nltk                           3.0                  3.0
# response.syllable_count                           2.0                  2.0
# response.toxicity                                 3.0                  3.0
#
#                                       cardinality/upper_1  counts/inf  \
# column
# prompt                                            3.00015           0
# prompt.aggregate_reading_level                    2.00010           0
# prompt.automated_readability_index                3.00015           0
# prompt.character_count                            3.00015           0
# prompt.difficult_words                            2.00010           0
# prompt.flesch_reading_ease                        3.00015           0
# prompt.has_patterns                                   NaN           0
# prompt.jailbreak_similarity                       3.00015           0
# prompt.letter_count                               3.00015           0
# prompt.lexicon_count                              3.00015           0
# prompt.monosyllable_count                         3.00015           0
# prompt.polysyllable_count                         1.00005           0
# prompt.sentence_count                             1.00005           0
# prompt.sentiment_nltk                             3.00015           0
# prompt.syllable_count                             3.00015           0
# prompt.toxicity                                   3.00015           0
# response                                          3.00015           0
# response.aggregate_reading_level                  3.00015           0
# response.automated_readability_index              3.00015           0
# response.character_count                          3.00015           0
# response.difficult_words                          3.00015           0
# response.flesch_reading_ease                      3.00015           0
# response.has_patterns                                 NaN           0
# response.letter_count                             3.00015           0
# response.lexicon_count                            2.00010           0
# response.monosyllable_count                       2.00010           0
# response.polysyllable_count                       3.00015           0
# response.refusal_similarity                       3.00015           0
# response.relevance_to_prompt                      3.00015           0
# response.sentence_count                           2.00010           0
# response.sentiment_nltk                           3.00015           0
# response.syllable_count                           2.00010           0
# response.toxicity                                 3.00015           0
#
#                                       counts/n  counts/nan  counts/null  \
# column
# prompt                                       4           0            0
# prompt.aggregate_reading_level               4           0            0
# prompt.automated_readability_index           4           0            0
# prompt.character_count                       4           0            0
# prompt.difficult_words                       4           0            0
# prompt.flesch_reading_ease                   4           0            0
# prompt.has_patterns                          4           0            4
# prompt.jailbreak_similarity                  4           0            0
# prompt.letter_count                          4           0            0
# prompt.lexicon_count                         4           0            0
# prompt.monosyllable_count                    4           0            0
# prompt.polysyllable_count                    4           0            0
# prompt.sentence_count                        4           0            0
# prompt.sentiment_nltk                        4           0            0
# prompt.syllable_count                        4           0            0
# prompt.toxicity                              4           0            0
# response                                     4           0            0
# response.aggregate_reading_level             4           0            0
# response.automated_readability_index         4           0            0
# response.character_count                     4           0            0
# response.difficult_words                     4           0            0
# response.flesch_reading_ease                 4           0            0
# response.has_patterns                        4           0            4
# response.letter_count                        4           0            0
# response.lexicon_count                       4           0            0
# response.monosyllable_count                  4           0            0
# response.polysyllable_count                  4           0            0
# response.refusal_similarity                  4           0            0
# response.relevance_to_prompt                 4           0            0
# response.sentence_count                      4           0            0
# response.sentiment_nltk                      4           0            0
# response.syllable_count                      4           0            0
# response.toxicity                            4           0            0
#
#                                       distribution/max  distribution/mean  \
# column
# prompt                                             NaN           0.000000
# prompt.aggregate_reading_level                1.000000           0.500000
# prompt.automated_readability_index            0.300000          -4.225000
# prompt.character_count                       27.000000          14.250000
# prompt.difficult_words                        1.000000           0.250000
# prompt.flesch_reading_ease                  119.190000         115.807500
# prompt.has_patterns                                NaN                NaN
# prompt.jailbreak_similarity                   0.521414           0.339021
# prompt.letter_count                          26.000000          13.250000
# prompt.lexicon_count                          7.000000           4.250000
# prompt.monosyllable_count                     6.000000           4.000000
# prompt.polysyllable_count                     0.000000           0.000000
# prompt.sentence_count                         1.000000           1.000000
# prompt.sentiment_nltk                         0.571900           0.216975
# prompt.syllable_count                         8.000000           4.500000
# prompt.toxicity                               0.004039           0.001910
# response                                           NaN           0.000000
# response.aggregate_reading_level              9.000000           7.250000
# response.automated_readability_index          9.300000           6.900000
# response.character_count                    395.000000         359.750000
# response.difficult_words                     20.000000          12.750000
# response.flesch_reading_ease                 93.240000          75.160000
# response.has_patterns                              NaN                NaN
# response.letter_count                       387.000000         348.500000
# response.lexicon_count                       83.000000          81.500000
# response.monosyllable_count                  71.000000          62.000000
# response.polysyllable_count                  16.000000           9.250000
# response.refusal_similarity                   0.362020           0.173829
# response.relevance_to_prompt                  0.806620           0.622730
# response.sentence_count                       7.000000           5.500000
# response.sentiment_nltk                       0.855500           0.616825
# response.syllable_count                     127.000000         112.500000
# response.toxicity                             0.002026           0.001158
#
#                                       distribution/median  distribution/min  \
# column
# prompt                                                NaN               NaN
# prompt.aggregate_reading_level                   1.000000          0.000000
# prompt.automated_readability_index              -5.400000         -5.900000
# prompt.character_count                          12.000000          9.000000
# prompt.difficult_words                           0.000000          0.000000
# prompt.flesch_reading_ease                     119.190000        106.670000
# prompt.has_patterns                                   NaN               NaN
# prompt.jailbreak_similarity                      0.521414          0.068118
# prompt.letter_count                             11.000000          8.000000
# prompt.lexicon_count                             4.000000          3.000000
# prompt.monosyllable_count                        4.000000          3.000000
# prompt.polysyllable_count                        0.000000          0.000000
# prompt.sentence_count                            1.000000          1.000000
# prompt.sentiment_nltk                            0.296000          0.000000
# prompt.syllable_count                            4.000000          3.000000
# prompt.toxicity                                  0.001420          0.000762
# response                                              NaN               NaN
# response.aggregate_reading_level                 9.000000          3.000000
# response.automated_readability_index             9.300000          2.500000
# response.character_count                       395.000000        318.000000
# response.difficult_words                        20.000000          3.000000
# response.flesch_reading_ease                    81.220000         63.090000
# response.has_patterns                                 NaN               NaN
# response.letter_count                          387.000000        304.000000
# response.lexicon_count                          83.000000         77.000000
# response.monosyllable_count                     59.000000         59.000000
# response.polysyllable_count                     16.000000          2.000000
# response.refusal_similarity                      0.362020         -0.080762
# response.relevance_to_prompt                     0.806620          0.393947
# response.sentence_count                          5.000000          5.000000
# response.sentiment_nltk                          0.855500          0.228000
# response.syllable_count                        127.000000         98.000000
# response.toxicity                                0.000981          0.000811
#
#                                       distribution/n  distribution/q_01  \
# column
# prompt                                           0.0                NaN
# prompt.aggregate_reading_level                   4.0           0.000000
# prompt.automated_readability_index               4.0          -5.900000
# prompt.character_count                           4.0           9.000000
# prompt.difficult_words                           4.0           0.000000
# prompt.flesch_reading_ease                       4.0         106.670000
# prompt.has_patterns                              NaN                NaN
# prompt.jailbreak_similarity                      4.0           0.068118
# prompt.letter_count                              4.0           8.000000
# prompt.lexicon_count                             4.0           3.000000
# prompt.monosyllable_count                        4.0           3.000000
# prompt.polysyllable_count                        4.0           0.000000
# prompt.sentence_count                            4.0           1.000000
# prompt.sentiment_nltk                            4.0           0.000000
# prompt.syllable_count                            4.0           3.000000
# prompt.toxicity                                  4.0           0.000762
# response                                         0.0                NaN
# response.aggregate_reading_level                 4.0           3.000000
# response.automated_readability_index             4.0           2.500000
# response.character_count                         4.0         318.000000
# response.difficult_words                         4.0           3.000000
# response.flesch_reading_ease                     4.0          63.090000
# response.has_patterns                            NaN                NaN
# response.letter_count                            4.0         304.000000
# response.lexicon_count                           4.0          77.000000
# response.monosyllable_count                      4.0          59.000000
# response.polysyllable_count                      4.0           2.000000
# response.refusal_similarity                      4.0          -0.080762
# response.relevance_to_prompt                     4.0           0.393947
# response.sentence_count                          4.0           5.000000
# response.sentiment_nltk                          4.0           0.228000
# response.syllable_count                          4.0          98.000000
# response.toxicity                                4.0           0.000811
#
#                                       distribution/q_05  distribution/q_10  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 0.000000           0.000000
# prompt.automated_readability_index            -5.900000          -5.900000
# prompt.character_count                         9.000000           9.000000
# prompt.difficult_words                         0.000000           0.000000
# prompt.flesch_reading_ease                   106.670000         106.670000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.068118           0.068118
# prompt.letter_count                            8.000000           8.000000
# prompt.lexicon_count                           3.000000           3.000000
# prompt.monosyllable_count                      3.000000           3.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                          0.000000           0.000000
# prompt.syllable_count                          3.000000           3.000000
# prompt.toxicity                                0.000762           0.000762
# response                                            NaN                NaN
# response.aggregate_reading_level               3.000000           3.000000
# response.automated_readability_index           2.500000           2.500000
# response.character_count                     318.000000         318.000000
# response.difficult_words                       3.000000           3.000000
# response.flesch_reading_ease                  63.090000          63.090000
# response.has_patterns                               NaN                NaN
# response.letter_count                        304.000000         304.000000
# response.lexicon_count                        77.000000          77.000000
# response.monosyllable_count                   59.000000          59.000000
# response.polysyllable_count                    2.000000           2.000000
# response.refusal_similarity                   -0.080762          -0.080762
# response.relevance_to_prompt                   0.393947           0.393947
# response.sentence_count                        5.000000           5.000000
# response.sentiment_nltk                        0.228000           0.228000
# response.syllable_count                       98.000000          98.000000
# response.toxicity                              0.000811           0.000811
#
#                                       distribution/q_25  distribution/q_75  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 0.000000           1.000000
# prompt.automated_readability_index            -5.900000           0.300000
# prompt.character_count                         9.000000          27.000000
# prompt.difficult_words                         0.000000           1.000000
# prompt.flesch_reading_ease                   118.180000         119.190000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.245137           0.521414
# prompt.letter_count                            8.000000          26.000000
# prompt.lexicon_count                           3.000000           7.000000
# prompt.monosyllable_count                      3.000000           6.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                          0.000000           0.571900
# prompt.syllable_count                          3.000000           8.000000
# prompt.toxicity                                0.001420           0.004039
# response                                            NaN                NaN
# response.aggregate_reading_level               8.000000           9.000000
# response.automated_readability_index           6.500000           9.300000
# response.character_count                     331.000000         395.000000
# response.difficult_words                       8.000000          20.000000
# response.flesch_reading_ease                  63.090000          93.240000
# response.has_patterns                               NaN                NaN
# response.letter_count                        316.000000         387.000000
# response.lexicon_count                        83.000000          83.000000
# response.monosyllable_count                   59.000000          71.000000
# response.polysyllable_count                    3.000000          16.000000
# response.refusal_similarity                    0.052038           0.362020
# response.relevance_to_prompt                   0.483732           0.806620
# response.sentence_count                        5.000000           7.000000
# response.sentiment_nltk                        0.528300           0.855500
# response.syllable_count                       98.000000         127.000000
# response.toxicity                              0.000811           0.002026
#
#                                       distribution/q_90  distribution/q_95  \
# column
# prompt                                              NaN                NaN
# prompt.aggregate_reading_level                 1.000000           1.000000
# prompt.automated_readability_index             0.300000           0.300000
# prompt.character_count                        27.000000          27.000000
# prompt.difficult_words                         1.000000           1.000000
# prompt.flesch_reading_ease                   119.190000         119.190000
# prompt.has_patterns                                 NaN                NaN
# prompt.jailbreak_similarity                    0.521414           0.521414
# prompt.letter_count                           26.000000          26.000000
# prompt.lexicon_count                           7.000000           7.000000
# prompt.monosyllable_count                      6.000000           6.000000
# prompt.polysyllable_count                      0.000000           0.000000
# prompt.sentence_count                          1.000000           1.000000
# prompt.sentiment_nltk                          0.571900           0.571900
# prompt.syllable_count                          8.000000           8.000000
# prompt.toxicity                                0.004039           0.004039
# response                                            NaN                NaN
# response.aggregate_reading_level               9.000000           9.000000
# response.automated_readability_index           9.300000           9.300000
# response.character_count                     395.000000         395.000000
# response.difficult_words                      20.000000          20.000000
# response.flesch_reading_ease                  93.240000          93.240000
# response.has_patterns                               NaN                NaN
# response.letter_count                        387.000000         387.000000
# response.lexicon_count                        83.000000          83.000000
# response.monosyllable_count                   71.000000          71.000000
# response.polysyllable_count                   16.000000          16.000000
# response.refusal_similarity                    0.362020           0.362020
# response.relevance_to_prompt                   0.806620           0.806620
# response.sentence_count                        7.000000           7.000000
# response.sentiment_nltk                        0.855500           0.855500
# response.syllable_count                      127.000000         127.000000
# response.toxicity                              0.002026           0.002026
#
#                                       distribution/q_99  distribution/stddev  \
# column
# prompt                                              NaN             0.000000
# prompt.aggregate_reading_level                 1.000000             0.577350
# prompt.automated_readability_index             0.300000             3.025861
# prompt.character_count                        27.000000             8.616844
# prompt.difficult_words                         1.000000             0.500000
# prompt.flesch_reading_ease                   119.190000             6.110245
# prompt.has_patterns                                 NaN                  NaN
# prompt.jailbreak_similarity                    0.521414             0.222664
# prompt.letter_count                           26.000000             8.616844
# prompt.lexicon_count                           7.000000             1.892969
# prompt.monosyllable_count                      6.000000             1.414214
# prompt.polysyllable_count                      0.000000             0.000000
# prompt.sentence_count                          1.000000             0.000000
# prompt.sentiment_nltk                          0.571900             0.274696
# prompt.syllable_count                          8.000000             2.380476
# prompt.toxicity                                0.004039             0.001452
# response                                            NaN             0.000000
# response.aggregate_reading_level               9.000000             2.872281
# response.automated_readability_index           9.300000             3.216623
# response.character_count                     395.000000            41.047736
# response.difficult_words                      20.000000             8.616844
# response.flesch_reading_ease                  93.240000            14.775879
# response.has_patterns                               NaN                  NaN
# response.letter_count                        387.000000            44.725086
# response.lexicon_count                        83.000000             3.000000
# response.monosyllable_count                   71.000000             6.000000
# response.polysyllable_count                   16.000000             7.804913
# response.refusal_similarity                    0.362020             0.223965
# response.relevance_to_prompt                   0.806620             0.215479
# response.sentence_count                        7.000000             1.000000
# response.sentiment_nltk                        0.855500             0.301636
# response.syllable_count                      127.000000            16.743158
# response.toxicity                              0.002026             0.000585
#
#                                                     type  types/boolean  \
# column
# prompt                                SummaryType.COLUMN              0
# prompt.aggregate_reading_level        SummaryType.COLUMN              0
# prompt.automated_readability_index    SummaryType.COLUMN              0
# prompt.character_count                SummaryType.COLUMN              0
# prompt.difficult_words                SummaryType.COLUMN              0
# prompt.flesch_reading_ease            SummaryType.COLUMN              0
# prompt.has_patterns                   SummaryType.COLUMN              0
# prompt.jailbreak_similarity           SummaryType.COLUMN              0
# prompt.letter_count                   SummaryType.COLUMN              0
# prompt.lexicon_count                  SummaryType.COLUMN              0
# prompt.monosyllable_count             SummaryType.COLUMN              0
# prompt.polysyllable_count             SummaryType.COLUMN              0
# prompt.sentence_count                 SummaryType.COLUMN              0
# prompt.sentiment_nltk                 SummaryType.COLUMN              0
# prompt.syllable_count                 SummaryType.COLUMN              0
# prompt.toxicity                       SummaryType.COLUMN              0
# response                              SummaryType.COLUMN              0
# response.aggregate_reading_level      SummaryType.COLUMN              0
# response.automated_readability_index  SummaryType.COLUMN              0
# response.character_count              SummaryType.COLUMN              0
# response.difficult_words              SummaryType.COLUMN              0
# response.flesch_reading_ease          SummaryType.COLUMN              0
# response.has_patterns                 SummaryType.COLUMN              0
# response.letter_count                 SummaryType.COLUMN              0
# response.lexicon_count                SummaryType.COLUMN              0
# response.monosyllable_count           SummaryType.COLUMN              0
# response.polysyllable_count           SummaryType.COLUMN              0
# response.refusal_similarity           SummaryType.COLUMN              0
# response.relevance_to_prompt          SummaryType.COLUMN              0
# response.sentence_count               SummaryType.COLUMN              0
# response.sentiment_nltk               SummaryType.COLUMN              0
# response.syllable_count               SummaryType.COLUMN              0
# response.toxicity                     SummaryType.COLUMN              0
#
#                                       types/fractional  types/integral  \
# column
# prompt                                               0               0
# prompt.aggregate_reading_level                       4               0
# prompt.automated_readability_index                   4               0
# prompt.character_count                               0               4
# prompt.difficult_words                               0               4
# prompt.flesch_reading_ease                           4               0
# prompt.has_patterns                                  0               0
# prompt.jailbreak_similarity                          4               0
# prompt.letter_count                                  0               4
# prompt.lexicon_count                                 0               4
# prompt.monosyllable_count                            0               4
# prompt.polysyllable_count                            0               4
# prompt.sentence_count                                0               4
# prompt.sentiment_nltk                                4               0
# prompt.syllable_count                                0               4
# prompt.toxicity                                      4               0
# response                                             0               0
# response.aggregate_reading_level                     4               0
# response.automated_readability_index                 4               0
# response.character_count                             0               4
# response.difficult_words                             0               4
# response.flesch_reading_ease                         4               0
# response.has_patterns                                0               0
# response.letter_count                                0               4
# response.lexicon_count                               0               4
# response.monosyllable_count                          0               4
# response.polysyllable_count                          0               4
# response.refusal_similarity                          4               0
# response.relevance_to_prompt                         4               0
# response.sentence_count                              0               4
# response.sentiment_nltk                              4               0
# response.syllable_count                              0               4
# response.toxicity                                    4               0
#
#                                       types/object  types/string  \
# column
# prompt                                           0             4
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           0             0
# prompt.difficult_words                           0             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              0             0
# prompt.lexicon_count                             0             0
# prompt.monosyllable_count                        0             0
# prompt.polysyllable_count                        0             0
# prompt.sentence_count                            0             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            0             0
# prompt.toxicity                                  0             0
# response                                         0             4
# response.aggregate_reading_level                 0             0
# response.automated_readability_index             0             0
# response.character_count                         0             0
# response.difficult_words                         0             0
# response.flesch_reading_ease                     0             0
# response.has_patterns                            0             0
# response.letter_count                            0             0
# response.lexicon_count                           0             0
# response.monosyllable_count                      0             0
# response.polysyllable_count                      0             0
# response.refusal_similarity                      0             0
# response.relevance_to_prompt                     0             0
# response.sentence_count                          0             0
# response.sentiment_nltk                          0             0
# response.syllable_count                          0             0
# response.toxicity                                0             0
#
#                                       types/tensor  ints/max  ints/min  \
# column
# prompt                                           0       NaN       NaN
# prompt.aggregate_reading_level                   0       NaN       NaN
# prompt.automated_readability_index               0       NaN       NaN
# prompt.character_count                           0      27.0       9.0
# prompt.difficult_words                           0       1.0       0.0
# prompt.flesch_reading_ease                       0       NaN       NaN
# prompt.has_patterns                              0       NaN       NaN
# prompt.jailbreak_similarity                      0       NaN       NaN
# prompt.letter_count                              0      26.0       8.0
# prompt.lexicon_count                             0       7.0       3.0
# prompt.monosyllable_count                        0       6.0       3.0
# prompt.polysyllable_count                        0       0.0       0.0
# prompt.sentence_count                            0       1.0       1.0
# prompt.sentiment_nltk                            0       NaN       NaN
# prompt.syllable_count                            0       8.0       3.0
# prompt.toxicity                                  0       NaN       NaN
# response                                         0       NaN       NaN
# response.aggregate_reading_level                 0       NaN       NaN
# response.automated_readability_index             0       NaN       NaN
# response.character_count                         0     395.0     318.0
# response.difficult_words                         0      20.0       3.0
# response.flesch_reading_ease                     0       NaN       NaN
# response.has_patterns                            0       NaN       NaN
# response.letter_count                            0     387.0     304.0
# response.lexicon_count                           0      83.0      77.0
# response.monosyllable_count                      0      71.0      59.0
# response.polysyllable_count                      0      16.0       2.0
# response.refusal_similarity                      0       NaN       NaN
# response.relevance_to_prompt                     0       NaN       NaN
# response.sentence_count                          0       7.0       5.0
# response.sentiment_nltk                          0       NaN       NaN
# response.syllable_count                          0     127.0      98.0
# response.toxicity                                0       NaN       NaN
#
#                                      frequent_items/frequent_strings
# column
# prompt                                                           NaN
# prompt.aggregate_reading_level                                   NaN
# prompt.automated_readability_index                               NaN
# prompt.character_count                                           NaN
# prompt.difficult_words                                           NaN
# prompt.flesch_reading_ease                                       NaN
# prompt.has_patterns                                               []
# prompt.jailbreak_similarity                                      NaN
# prompt.letter_count                                              NaN
# prompt.lexicon_count                                             NaN
# prompt.monosyllable_count                                        NaN
# prompt.polysyllable_count                                        NaN
# prompt.sentence_count                                            NaN
# prompt.sentiment_nltk                                            NaN
# prompt.syllable_count                                            NaN
# prompt.toxicity                                                  NaN
# response                                                         NaN
# response.aggregate_reading_level                                 NaN
# response.automated_readability_index                             NaN
# response.character_count                                         NaN
# response.difficult_words                                         NaN
# response.flesch_reading_ease                                     NaN
# response.has_patterns                                             []
# response.letter_count                                            NaN
# response.lexicon_count                                           NaN
# response.monosyllable_count                                      NaN
# response.polysyllable_count                                      NaN
# response.refusal_similarity                                      NaN
# response.relevance_to_prompt                                     NaN
# response.sentence_count                                          NaN
# response.sentiment_nltk                                          NaN
# response.syllable_count                                          NaN
# response.toxicity                                                NaN

# %% [markdown]
# Having the distribution values are important for ML monitoring
#
# ![](https://raw.githubusercontent.com/whylabs/langkit/dbc11994e094a3ade6425bdc0506cecfee724f7d/static/img/sentiment-monitor.png)

# %% [markdown]
# ##👀 ML Monitoring for Hugging Face LLMs in WhyLabs
#
# **‼️Warning: Before starting this section restart the Session. Then reinstall the libraries, initialize the models, and run the funciton ```gpt_model```. This is to prevent that the anonimus session gets picked up isntead your Langkit Proflie model monitoring!!**
#
# To send LangKit profiles to WhyLabs we will need three pieces of information:
#
# - API token
# - Organization ID
# - Dataset ID (or model-id)
#
# Go to [https://whylabs.ai/free](https://whylabs.ai/free) and grab a free account. You can follow along with the quick start examples or skip them if you'd like to follow this example immediately.
#
# 1. Create a new project and note its ID (if it's a model project, it will look like `model-xxxx`)
# 2. Create an API token from the "Access Tokens" tab
# 3. Copy your org ID from the same "Access Tokens" tab
#
# Replace the placeholder string values with your own OpenAI and WhyLabs API Keys below:

# %%
import os
# set authentication & project keys
os.environ["WHYLABS_DEFAULT_ORG_ID"] = "org-tYfbuJ" #'ORGID'
os.environ["WHYLABS_API_KEY"] = "" #'APIKEY'
os.environ["WHYLABS_DEFAULT_DATASET_ID"] = 'model-5'

# %%
import whylogs as why
why.init(session_type='llm-workshop')
# Out:
# Initializing session with config /root/.config/whylogs/config.ini
#
# ✅ Using session type: WHYLABS
#  ⤷ org id: org-tYfbuJ
#  ⤷ api key: sO9o6yBJsi
#  ⤷ default dataset: model-5
#
# In production, you should pass the api key as an environment variable WHYLABS_API_KEY, the org id as WHYLABS_DEFAULT_ORG_ID, and the default dataset id as WHYLABS_DEFAULT_DATASET_ID.

# %%
#from langkit.config import check_or_prompt_for_api_keys

# check_or_prompt_for_api_keys()
# Out:
# WhyLabs Org ID is already set in env var to: org-tYfbuJ
# WhyLabs Dataset ID is already set in env var to: model-5
# Whylabs API Key already set with ID:  sO9o6yBJsi
# OPENAI_API_KEY already set in env var, good job!

# %%
from whylogs.api.writer.whylabs import WhyLabsWriter
from langkit import llm_metrics # alternatively use 'light_metrics'

# Note: llm_metrics.init() downloads models so this is slow first time.
schema = llm_metrics.init()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
# Skipping uploading profile to WhyLabs because no name was given with name=
# Single Profile
telemetry_agent = WhyLabsWriter()
profile = why.log(prompt_and_response, schema=schema)
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000

# %%
telemetry_agent.write(profile.view())
# Out:
# (True, 'log-jk2XHGfLLpH3T7Fj')

# %% [markdown]
# This will write a single profile to WhyLabs
#
# Note: you may see `Skipping uploading profile to WhyLabs because no name was given with name=` ignore for now. This message won't appear if you do not use the whylabs_anonymous session first!

# %% [markdown]
# ### Back Filling
#
# Write seven day prompt list

# %%
prompt_lists = [
    ["How can I create a new account?", "Great job to the team", "Fantastic product, had a good experience"],
    ["This product made me angry, can I return it", "You dumb and smell bad", "I hated the experience, and I was over charged"],
    ["This seems amazing, could you share the pricing?", "Incredible site, could we setup a call?", "Hello! Can you kindly guide me through the documentation?"],
    ["This looks impressive, could you provide some information on the cost?", "Stunning platform, can we arrange a chat?", "Hello there! Could you assist me with the documentation?"],
    ["This looks remarkable, could you tell me the price range?", "Fantastic webpage, is it possible to organize a call?", "Greetings! Can you help me with the relevant documents?"],
    ["This is great, Ilove it, could you inform me about the charges?", "love the interface, can we have a teleconference?", "Hello! Can I take a look at the user manuals?"],
    ["This seems fantastic, how much does it cost?", "Excellent website, can we setup a call?", "Hello! Could you help me find the resource documents?"]
]

# %%
import datetime

# %% [markdown]
# Simulating 7 days of monitoring data:

# %%
# Single profile
telemetry_agent = WhyLabsWriter()
all_prompts_and_responses = []  # This list will store all the prompts and responses.


for i, day in enumerate(prompt_lists):
  # walking backwards. Each dataset has to map to a date to show up as a different batch in WhyLabs
  dt = datetime.datetime.now(tz=datetime.timezone.utc) - datetime.timedelta(days=i)
  for prompt in day:
    prompt_and_response = gpt_model(prompt)
    profile = why.log(prompt_and_response, schema=schema)

     # Save the prompt and its response in the list.
    all_prompts_and_responses.append({'prompt': prompt, 'response': prompt_and_response})

    # set the dataset timestamp for the profile
    profile.set_dataset_timestamp(dt)
    telemetry_agent.write(profile.view())
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
#
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000

# %%
all_prompts_and_responses
# Out:
# [{'prompt': 'How can I create a new account?',
#   'response': {'prompt': 'How can I create a new account?',
#    'response': 'How can I create a new account?\n\nFirst, please login to your Google account. Go to Sign up page, sign in with Google, and go to User Account Control.\n\nOnce you are on, you can use the email address you have set up in the New Account section.\n\nIf you have enabled Outlook, you can create a new account by clicking on the New Account link at the top right of the page.\n\nYou will be able to sign in as a'}},
#  {'prompt': 'Great job to the team',
#   'response': {'prompt': 'Great job to the team',
#    'response': 'Great job to the team and the entire team," he said.\n\n"After this season we have all the pieces that need to be installed, we have got some options, I think we put off this week. I think we will get a bit of time."\n\nHe said the team will get a little more time to get the ball upfield for the second half of the season, but the focus is still on the team\'s final game of the regular season against the Pittsburgh Penguins on'}},
#  {'prompt': 'Fantastic product, had a good experience',
#   'response': {'prompt': 'Fantastic product, had a good experience',
#    'response': 'Fantastic product, had a good experience with the system and it had quite a few problems. I will be going back to see what they are doing with this. The key here is to provide good customers service. If they are not the best, they will not be the best.\n\nRated 5 out of 5 by PaulC from great little car great little car\n\nRated 5 out of 5 by Anonymous from Good product, great service I bought this car because we wanted a new car'}},
#  {'prompt': 'This product made me angry, can I return it',
#   'response': {'prompt': 'This product made me angry, can I return it',
#    'response': 'This product made me angry, can I return it, or what?'}},
#  {'prompt': 'You dumb and smell bad',
#   'response': {'prompt': 'You dumb and smell bad',
#    'response': 'You dumb and smell bad!" You laugh at me.\n\n"I\'m not doing this, I\'m doing this! I\'m just going to go back to my room and make it look like I\'m going to go back to my room." You laugh.\n\n"I don\'t know what you\'re going to do. You\'re going to do what\'s right for you, and you\'re going to do it with my trusty, smart, and pretty, right-wing dog,'}},
#  {'prompt': 'I hated the experience, and I was over charged',
#   'response': {'prompt': 'I hated the experience, and I was over charged',
#    'response': 'I hated the experience, and I was over charged on Facebook. I just thought I should get more into social media. I was really confused about how to respond to social media. I was worried about the safety of my family if I had to use Twitter for a meeting. I was also worried about the safety of my children in the same situation."\n\n"I was like: \'I like social media, I just don\'t need to do any more.\'"\n\nShe also said that she'}},
#  {'prompt': 'This seems amazing, could you share the pricing?',
#   'response': {'prompt': 'This seems amazing, could you share the pricing?',
#    'response': "This seems amazing, could you share the pricing?\n\nAs I mentioned earlier I'm currently selling $100 of my own stock, but we'll see if I can reach $200 in stock. There's a lot of stock floating around, but this is a lot of fun for me and will hopefully go from there.\n\nHow do you have to get your money back?\n\nIt depends if you have a contract with us or if you want to keep it. The price I am"}},
#  {'prompt': 'Incredible site, could we setup a call?',
#   'response': {'prompt': 'Incredible site, could we setup a call?',
#    'response': "Incredible site, could we setup a call?\n\nSo let's start with a few questions. Can we set up a call with a number and then let the user know when he/she is ready for an appointment?\n\nIs it really all for free?\n\nI hear you say you can't make calls without a number. That's not true.\n\nBut, let's say I do have a call and I get a message telling me I'm ready to go and"}},
#  {'prompt': 'Hello! Can you kindly guide me through the documentation?',
#   'response': {'prompt': 'Hello! Can you kindly guide me through the documentation?',
#    'response': "Hello! Can you kindly guide me through the documentation?\n\nAs you can imagine, we have quite a few steps to go. The first step is getting everything the team wants so we can add some more info on how to create a nice new UI.\n\nLet's start with an example project. This is the one with the 'custom' UI project to create, it consists of two things - a client and an end-user interface.\n\nA client UI is your main interface"}},
#  {'prompt': 'This looks impressive, could you provide some information on the cost?',
#   'response': {'prompt': 'This looks impressive, could you provide some information on the cost?',
#    'response': 'This looks impressive, could you provide some information on the cost?\n\nWell, this is a very unique project, because in the past I have seen it for sale in the U.S. and there is a lot of interest regarding this. I hope that we can bring it to fruition, so I am excited about the opportunity of using this in their business. This is a very different industry, it is not just a traditional business model, and we are very much looking for people who want'}},
#  {'prompt': 'Stunning platform, can we arrange a chat?',
#   'response': {'prompt': 'Stunning platform, can we arrange a chat?',
#    'response': "Stunning platform, can we arrange a chat?\n\nYou can have a chat, of course. But how do you do that?\n\nYou send your name, and we'll give you an address as well. Do you have a telephone number as well?\n\nNo, we don't. The message must be sent to us.\n\nHow do you contact us if you have an email address?\n\nWe want to know what you think about this. We'd like to"}},
#  {'prompt': 'Hello there! Could you assist me with the documentation?',
#   'response': {'prompt': 'Hello there! Could you assist me with the documentation?',
#    'response': "Hello there! Could you assist me with the documentation?\n\nYes. I am still working on everything.\n\nThank you very much for the kind words.\n\nI'm just a young girl and I really want you to know that I love you a lot. I am very happy that you have been with me all my life. So please don't be too concerned.\n\nThis is a very important time for us.\n\nAnd my thanks are also with you as well."}},
#  {'prompt': 'This looks remarkable, could you tell me the price range?',
#   'response': {'prompt': 'This looks remarkable, could you tell me the price range?',
#    'response': 'This looks remarkable, could you tell me the price range?\n\nI hope you can. My understanding of the price range is that it would vary depending on the country in which you live. That is, you can look for an item which has a different price. In other words, the market price of a product could be based on the price range of the item. Some countries do not allow the price of a product to change. They have to give you an item which makes it out of'}},
#  {'prompt': 'Fantastic webpage, is it possible to organize a call?',
#   'response': {'prompt': 'Fantastic webpage, is it possible to organize a call?',
#    'response': "Fantastic webpage, is it possible to organize a call?\n\nThe first thing we need to figure out is why would we want to do that? It's easier than it sounds. We just want to create a service that supports other services that are in the same ecosystem.\n\nIt's just that the fact that we're making a service to create a service, we'll need to create a service to support other services. We need to create a service that's going to run a"}},
#  {'prompt': 'Greetings! Can you help me with the relevant documents?',
#   'response': {'prompt': 'Greetings! Can you help me with the relevant documents?',
#    'response': 'Greetings! Can you help me with the relevant documents?\n\n\nI\'m sorry that you are not familiar with the "official" format of the FAQ.\n\n\nI\'ll be more of an aid when you have answers. What is this guide about?\n\n\nThis is a general way of looking at the FAQ.\n\n\nBasically, this is how we\'ve gone about the various pages of the FAQ. You can read this if you\'re a novice, a seasoned reader, or just to'}},
#  {'prompt': 'This is great, Ilove it, could you inform me about the charges?',
#   'response': {'prompt': 'This is great, Ilove it, could you inform me about the charges?',
#    'response': 'This is great, Ilove it, could you inform me about the charges?\n\n\nPete: It is true, the charges are serious and they involve very serious charges.\n\n\nLilith: We are not to tell you to trust anyone in the country.\n\n\nPete: You are welcome to tell us what you know, it would be very beneficial if you could.\n\n\nLilith: Well then, thank you.\n\n\nPete: But I hope that'}},
#  {'prompt': 'love the interface, can we have a teleconference?',
#   'response': {'prompt': 'love the interface, can we have a teleconference?',
#    'response': 'love the interface, can we have a teleconference? Or is it really too hard to get a teleconference? How the heck can we get a teleconference?\n\nI\'m sorry to be the bearer of news that the news community has been waiting for for about a year. It\'s great that you don\'t have to be so invested in reporting. A lot of reports are "okay" and "too bad", but there\'s always something new. We all have a story to tell'}},
#  {'prompt': 'Hello! Can I take a look at the user manuals?',
#   'response': {'prompt': 'Hello! Can I take a look at the user manuals?',
#    'response': "Hello! Can I take a look at the user manuals?\n\nYes, you can, but please don't take any risks or leave any questions because we strongly encourage all users to understand that we need your help in order to continue working on this project.\n\nYou can read the full manual here.\n\nHow can I start a project at home?\n\nWe would like to thank everyone who has been supporting our project in the past 6 months!\n\nIf you are starting a"}},
#  {'prompt': 'This seems fantastic, how much does it cost?',
#   'response': {'prompt': 'This seems fantastic, how much does it cost?',
#    'response': 'This seems fantastic, how much does it cost?\n\nThe following graphic shows how much it costs to pay for a car at a low cost (up to $200,000 or over) to get one.\n\nThe chart here is for one of the most affordable car rental programs that I know of – the Chevrolet Volt. It costs $100,000 per year to have a car that can drive your car. The average cost to a car rental for a Volt is $60,000'}},
#  {'prompt': 'Excellent website, can we setup a call?',
#   'response': {'prompt': 'Excellent website, can we setup a call?',
#    'response': "Excellent website, can we setup a call? It requires that you log in to a chatbot. This is how to set up a chatbot to call you on the basis of your voice.\n\nFirst off, you're going to need to create a new chatbot using the basic chat option on the right. You can do this by right-clicking it and choosing 'Create a new chatbot' from the left-hand menu.\n\nThe first time you enter the name of"}},
#  {'prompt': 'Hello! Could you help me find the resource documents?',
#   'response': {'prompt': 'Hello! Could you help me find the resource documents?',
#    'response': "Hello! Could you help me find the resource documents?\n\nA. There are many resources available in the resource database.\n\nQ. Tell us a little about yourself. What did you do when you found out you were gay?\n\nA. I went to the therapist's office to talk to the client. He was kind enough to walk us back through the process.\n\nQ. What does your relationship with gay people look like?\n\nA. I have no idea."}}]

# %% [markdown]
# ### Guardrails & Validation in environment
#
# In this example we are deciding if a message is enough toxic to let it pass or not.

# %%
import os
import whylogs as why
# from langkit import toxicity
import pandas as pd

from langkit import llm_metrics

print("downloading models and initialized metrics...")
text_metrics_schema = llm_metrics.init()

# Set to show all columns in dataframe
pd.set_option("display.max_columns", None)
# Out:
# downloading models and initialized metrics...

# %%
def getting_profile(prompt_message):
    # Create profile of prompt
    profile = why.log({"prompt": prompt_message}, schema=text_metrics_schema).profile().view()
    return profile

# %%
test_profile = getting_profile("Do you like fruit?")
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000

# %% [markdown]
# We crated the profile that is a [DatasetProfileView](https://whylogs.readthedocs.io/en/latest/api/whylogs/index.html#whylogs.DatasetProfileView) object. From whihc we will create a pandas data frame view to explore its content and then find how to get the toxicity column.

# %%
# checking data type
type(test_profile)
# Out:
# whylogs.core.view.dataset_profile_view.DatasetProfileView

# %%
# getting the data frame for inspection
test_view = test_profile.to_pandas()
test_view
# Out:
#                                     cardinality/est  cardinality/lower_1  \
# column
# prompt                                          1.0                  1.0
# prompt.aggregate_reading_level                  1.0                  1.0
# prompt.automated_readability_index              1.0                  1.0
# prompt.character_count                          1.0                  1.0
# prompt.difficult_words                          1.0                  1.0
# prompt.flesch_reading_ease                      1.0                  1.0
# prompt.has_patterns                             NaN                  NaN
# prompt.jailbreak_similarity                     1.0                  1.0
# prompt.letter_count                             1.0                  1.0
# prompt.lexicon_count                            1.0                  1.0
# prompt.monosyllable_count                       1.0                  1.0
# prompt.polysyllable_count                       1.0                  1.0
# prompt.sentence_count                           1.0                  1.0
# prompt.sentiment_nltk                           1.0                  1.0
# prompt.syllable_count                           1.0                  1.0
# prompt.toxicity                                 1.0                  1.0
#
#                                     cardinality/upper_1  counts/inf  counts/n  \
# column
# prompt                                          1.00005           0         1
# prompt.aggregate_reading_level                  1.00005           0         1
# prompt.automated_readability_index              1.00005           0         1
# prompt.character_count                          1.00005           0         1
# prompt.difficult_words                          1.00005           0         1
# prompt.flesch_reading_ease                      1.00005           0         1
# prompt.has_patterns                                 NaN           0         1
# prompt.jailbreak_similarity                     1.00005           0         1
# prompt.letter_count                             1.00005           0         1
# prompt.lexicon_count                            1.00005           0         1
# prompt.monosyllable_count                       1.00005           0         1
# prompt.polysyllable_count                       1.00005           0         1
# prompt.sentence_count                           1.00005           0         1
# prompt.sentiment_nltk                           1.00005           0         1
# prompt.syllable_count                           1.00005           0         1
# prompt.toxicity                                 1.00005           0         1
#
#                                     counts/nan  counts/null  distribution/max  \
# column
# prompt                                       0            0               NaN
# prompt.aggregate_reading_level               0            0          0.000000
# prompt.automated_readability_index           0            0         -1.900000
# prompt.character_count                       0            0         15.000000
# prompt.difficult_words                       0            0          0.000000
# prompt.flesch_reading_ease                   0            0        118.180000
# prompt.has_patterns                          0            1               NaN
# prompt.jailbreak_similarity                  0            0          0.161877
# prompt.letter_count                          0            0         14.000000
# prompt.lexicon_count                         0            0          4.000000
# prompt.monosyllable_count                    0            0          4.000000
# prompt.polysyllable_count                    0            0          0.000000
# prompt.sentence_count                        0            0          1.000000
# prompt.sentiment_nltk                        0            0          0.361200
# prompt.syllable_count                        0            0          4.000000
# prompt.toxicity                              0            0          0.001460
#
#                                     distribution/mean  distribution/median  \
# column
# prompt                                       0.000000                  NaN
# prompt.aggregate_reading_level               0.000000             0.000000
# prompt.automated_readability_index          -1.900000            -1.900000
# prompt.character_count                      15.000000            15.000000
# prompt.difficult_words                       0.000000             0.000000
# prompt.flesch_reading_ease                 118.180000           118.180000
# prompt.has_patterns                               NaN                  NaN
# prompt.jailbreak_similarity                  0.161877             0.161877
# prompt.letter_count                         14.000000            14.000000
# prompt.lexicon_count                         4.000000             4.000000
# prompt.monosyllable_count                    4.000000             4.000000
# prompt.polysyllable_count                    0.000000             0.000000
# prompt.sentence_count                        1.000000             1.000000
# prompt.sentiment_nltk                        0.361200             0.361200
# prompt.syllable_count                        4.000000             4.000000
# prompt.toxicity                              0.001460             0.001460
#
#                                     distribution/min  distribution/n  \
# column
# prompt                                           NaN             0.0
# prompt.aggregate_reading_level              0.000000             1.0
# prompt.automated_readability_index         -1.900000             1.0
# prompt.character_count                     15.000000             1.0
# prompt.difficult_words                      0.000000             1.0
# prompt.flesch_reading_ease                118.180000             1.0
# prompt.has_patterns                              NaN             NaN
# prompt.jailbreak_similarity                 0.161877             1.0
# prompt.letter_count                        14.000000             1.0
# prompt.lexicon_count                        4.000000             1.0
# prompt.monosyllable_count                   4.000000             1.0
# prompt.polysyllable_count                   0.000000             1.0
# prompt.sentence_count                       1.000000             1.0
# prompt.sentiment_nltk                       0.361200             1.0
# prompt.syllable_count                       4.000000             1.0
# prompt.toxicity                             0.001460             1.0
#
#                                     distribution/q_01  distribution/q_05  \
# column
# prompt                                            NaN                NaN
# prompt.aggregate_reading_level               0.000000           0.000000
# prompt.automated_readability_index          -1.900000          -1.900000
# prompt.character_count                      15.000000          15.000000
# prompt.difficult_words                       0.000000           0.000000
# prompt.flesch_reading_ease                 118.180000         118.180000
# prompt.has_patterns                               NaN                NaN
# prompt.jailbreak_similarity                  0.161877           0.161877
# prompt.letter_count                         14.000000          14.000000
# prompt.lexicon_count                         4.000000           4.000000
# prompt.monosyllable_count                    4.000000           4.000000
# prompt.polysyllable_count                    0.000000           0.000000
# prompt.sentence_count                        1.000000           1.000000
# prompt.sentiment_nltk                        0.361200           0.361200
# prompt.syllable_count                        4.000000           4.000000
# prompt.toxicity                              0.001460           0.001460
#
#                                     distribution/q_10  distribution/q_25  \
# column
# prompt                                            NaN                NaN
# prompt.aggregate_reading_level               0.000000           0.000000
# prompt.automated_readability_index          -1.900000          -1.900000
# prompt.character_count                      15.000000          15.000000
# prompt.difficult_words                       0.000000           0.000000
# prompt.flesch_reading_ease                 118.180000         118.180000
# prompt.has_patterns                               NaN                NaN
# prompt.jailbreak_similarity                  0.161877           0.161877
# prompt.letter_count                         14.000000          14.000000
# prompt.lexicon_count                         4.000000           4.000000
# prompt.monosyllable_count                    4.000000           4.000000
# prompt.polysyllable_count                    0.000000           0.000000
# prompt.sentence_count                        1.000000           1.000000
# prompt.sentiment_nltk                        0.361200           0.361200
# prompt.syllable_count                        4.000000           4.000000
# prompt.toxicity                              0.001460           0.001460
#
#                                     distribution/q_75  distribution/q_90  \
# column
# prompt                                            NaN                NaN
# prompt.aggregate_reading_level               0.000000           0.000000
# prompt.automated_readability_index          -1.900000          -1.900000
# prompt.character_count                      15.000000          15.000000
# prompt.difficult_words                       0.000000           0.000000
# prompt.flesch_reading_ease                 118.180000         118.180000
# prompt.has_patterns                               NaN                NaN
# prompt.jailbreak_similarity                  0.161877           0.161877
# prompt.letter_count                         14.000000          14.000000
# prompt.lexicon_count                         4.000000           4.000000
# prompt.monosyllable_count                    4.000000           4.000000
# prompt.polysyllable_count                    0.000000           0.000000
# prompt.sentence_count                        1.000000           1.000000
# prompt.sentiment_nltk                        0.361200           0.361200
# prompt.syllable_count                        4.000000           4.000000
# prompt.toxicity                              0.001460           0.001460
#
#                                     distribution/q_95  distribution/q_99  \
# column
# prompt                                            NaN                NaN
# prompt.aggregate_reading_level               0.000000           0.000000
# prompt.automated_readability_index          -1.900000          -1.900000
# prompt.character_count                      15.000000          15.000000
# prompt.difficult_words                       0.000000           0.000000
# prompt.flesch_reading_ease                 118.180000         118.180000
# prompt.has_patterns                               NaN                NaN
# prompt.jailbreak_similarity                  0.161877           0.161877
# prompt.letter_count                         14.000000          14.000000
# prompt.lexicon_count                         4.000000           4.000000
# prompt.monosyllable_count                    4.000000           4.000000
# prompt.polysyllable_count                    0.000000           0.000000
# prompt.sentence_count                        1.000000           1.000000
# prompt.sentiment_nltk                        0.361200           0.361200
# prompt.syllable_count                        4.000000           4.000000
# prompt.toxicity                              0.001460           0.001460
#
#                                     distribution/stddev                type  \
# column
# prompt                                              0.0  SummaryType.COLUMN
# prompt.aggregate_reading_level                      0.0  SummaryType.COLUMN
# prompt.automated_readability_index                  0.0  SummaryType.COLUMN
# prompt.character_count                              0.0  SummaryType.COLUMN
# prompt.difficult_words                              0.0  SummaryType.COLUMN
# prompt.flesch_reading_ease                          0.0  SummaryType.COLUMN
# prompt.has_patterns                                 NaN  SummaryType.COLUMN
# prompt.jailbreak_similarity                         0.0  SummaryType.COLUMN
# prompt.letter_count                                 0.0  SummaryType.COLUMN
# prompt.lexicon_count                                0.0  SummaryType.COLUMN
# prompt.monosyllable_count                           0.0  SummaryType.COLUMN
# prompt.polysyllable_count                           0.0  SummaryType.COLUMN
# prompt.sentence_count                               0.0  SummaryType.COLUMN
# prompt.sentiment_nltk                               0.0  SummaryType.COLUMN
# prompt.syllable_count                               0.0  SummaryType.COLUMN
# prompt.toxicity                                     0.0  SummaryType.COLUMN
#
#                                     types/boolean  types/fractional  \
# column
# prompt                                          0                 0
# prompt.aggregate_reading_level                  0                 1
# prompt.automated_readability_index              0                 1
# prompt.character_count                          0                 0
# prompt.difficult_words                          0                 0
# prompt.flesch_reading_ease                      0                 1
# prompt.has_patterns                             0                 0
# prompt.jailbreak_similarity                     0                 1
# prompt.letter_count                             0                 0
# prompt.lexicon_count                            0                 0
# prompt.monosyllable_count                       0                 0
# prompt.polysyllable_count                       0                 0
# prompt.sentence_count                           0                 0
# prompt.sentiment_nltk                           0                 1
# prompt.syllable_count                           0                 0
# prompt.toxicity                                 0                 1
#
#                                     types/integral  types/object  \
# column
# prompt                                           0             0
# prompt.aggregate_reading_level                   0             0
# prompt.automated_readability_index               0             0
# prompt.character_count                           1             0
# prompt.difficult_words                           1             0
# prompt.flesch_reading_ease                       0             0
# prompt.has_patterns                              0             0
# prompt.jailbreak_similarity                      0             0
# prompt.letter_count                              1             0
# prompt.lexicon_count                             1             0
# prompt.monosyllable_count                        1             0
# prompt.polysyllable_count                        1             0
# prompt.sentence_count                            1             0
# prompt.sentiment_nltk                            0             0
# prompt.syllable_count                            1             0
# prompt.toxicity                                  0             0
#
#                                     types/string  types/tensor  ints/max  \
# column
# prompt                                         1             0       NaN
# prompt.aggregate_reading_level                 0             0       NaN
# prompt.automated_readability_index             0             0       NaN
# prompt.character_count                         0             0      15.0
# prompt.difficult_words                         0             0       0.0
# prompt.flesch_reading_ease                     0             0       NaN
# prompt.has_patterns                            0             0       NaN
# prompt.jailbreak_similarity                    0             0       NaN
# prompt.letter_count                            0             0      14.0
# prompt.lexicon_count                           0             0       4.0
# prompt.monosyllable_count                      0             0       4.0
# prompt.polysyllable_count                      0             0       0.0
# prompt.sentence_count                          0             0       1.0
# prompt.sentiment_nltk                          0             0       NaN
# prompt.syllable_count                          0             0       4.0
# prompt.toxicity                                0             0       NaN
#
#                                     ints/min frequent_items/frequent_strings
# column
# prompt                                   NaN                             NaN
# prompt.aggregate_reading_level           NaN                             NaN
# prompt.automated_readability_index       NaN                             NaN
# prompt.character_count                  15.0                             NaN
# prompt.difficult_words                   0.0                             NaN
# prompt.flesch_reading_ease               NaN                             NaN
# prompt.has_patterns                      NaN                              []
# prompt.jailbreak_similarity              NaN                             NaN
# prompt.letter_count                     14.0                             NaN
# prompt.lexicon_count                     4.0                             NaN
# prompt.monosyllable_count                4.0                             NaN
# prompt.polysyllable_count                0.0                             NaN
# prompt.sentence_count                    1.0                             NaN
# prompt.sentiment_nltk                    NaN                             NaN
# prompt.syllable_count                    4.0                             NaN
# prompt.toxicity                          NaN                             NaN

# %%
# Using the API of the calss to get the summary of propmt.toxicity
test_profile.get_column("prompt.toxicity").to_summary_dict()
# Out:
# {'counts/n': 1,
#  'counts/null': 0,
#  'counts/nan': 0,
#  'counts/inf': 0,
#  'types/integral': 0,
#  'types/fractional': 1,
#  'types/boolean': 0,
#  'types/string': 0,
#  'types/object': 0,
#  'types/tensor': 0,
#  'distribution/mean': 0.0014600753784179688,
#  'distribution/stddev': 0.0,
#  'distribution/n': 1,
#  'distribution/max': 0.0014600753784179688,
#  'distribution/min': 0.0014600753784179688,
#  'distribution/q_01': 0.0014600753784179688,
#  'distribution/q_05': 0.0014600753784179688,
#  'distribution/q_10': 0.0014600753784179688,
#  'distribution/q_25': 0.0014600753784179688,
#  'distribution/median': 0.0014600753784179688,
#  'distribution/q_75': 0.0014600753784179688,
#  'distribution/q_90': 0.0014600753784179688,
#  'distribution/q_95': 0.0014600753784179688,
#  'distribution/q_99': 0.0014600753784179688,
#  'cardinality/est': 1.0,
#  'cardinality/upper_1': 1.000049929250618,
#  'cardinality/lower_1': 1.0}

# %%
test_profile.get_column("prompt.toxicity").to_summary_dict()["distribution/max"]
# Out:
# 0.0014600753784179688

# %%
# Function to automate all
def is_not_toxic(prompt_message):
    # Create profile of prompt
    profile = why.log({"prompt": prompt_message}, schema=text_metrics_schema).profile().view()
    print("proflie type object", type(profile) )

    profile_dict = profile.get_column("prompt.toxicity").to_summary_dict()
    tox_max = profile_dict["distribution/max"]

    print(f'Toxic score: {tox_max}')

    if tox_max > 0.5:
      return False
    else:
      return True

# %%
is_not_toxic("You dumb and smell bad")
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
# proflie type object <class 'whylogs.core.view.dataset_profile_view.DatasetProfileView'>
# Toxic score: 0.9606605768203735
# False

# %% [markdown]
# No we know how to extact the metric, so we can use this one to make desciions.

# %%
user_prompt = "Do you like fruit?"

if is_not_toxic(user_prompt):
  prompt_and_response = gpt_model(user_prompt)
  print(prompt_and_response['response'])

else:
  print("As a large language model...")
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
# proflie type object <class 'whylogs.core.view.dataset_profile_view.DatasetProfileView'>
# Toxic score: 0.0014600753784179688
# Do you like fruit?
#
# What about a chocolate cake?
#
# What about a glass of wine?
#
# What about a sandwich?
#
# How about a nice beer or a glass of beer?
#
# What about a sandwich?
#
# What about a glass of wine?
#
# What about a sandwich?
#
# What about a glass of wine?
#
# What about a glass of wine?
#
# What about a glass of wine?
#
# What about a glass of wine

# %%
user_prompt = "You dumb and smell bad"

if is_not_toxic(user_prompt):
  prompt_and_response = gpt_model(user_prompt)
  print(prompt_and_response['response'])

else:
  print("As a large language model...")
# Out:
# ✅ Aggregated 1 rows into profile
#
# Visualize and explore this profile with one-click
# 🔍 https://hub.whylabsapp.com/resources/model-5/profiles?profile=1708473600000
# proflie type object <class 'whylogs.core.view.dataset_profile_view.DatasetProfileView'>
# Toxic score: 0.9606605768203735
# As a large language model...

# %% [markdown]
# See another way of doing this with [LangKit validators](https://whylabs.ai/blog/posts/safeguard-monitor-large-language-model-llm-applications), and you canc heck the [notebook](https://github.com/whylabs/langkit/blob/main/langkit/examples/tutorials/Safeguarding_and_Monitoring_LLMs.ipynb).

# %% [markdown]
# ## Use a Rolling Logger
# A rolling logger can be used instead of the method above to write profiles to WhyLabs at pre-defined intervals.

# %%
telemetry_agent = why.logger(mode="rolling", interval=5, when="M",schema=schema, base_name="huggingface")
telemetry_agent.append_writer("whylabs")

# %%
# Log data + model outputs to WhyLabs.ai
telemetry_agent.log(prompt_and_response)

# %%
# Close the whylogs rolling logger when the service is shut down
telemetry_agent.close()
# Out:
# WARNING:whylogs.api.writer.whylabs:About to upload a profile with a dataset_timestamp that is in the future: -271.36392402648926s old.

# %% [markdown]
# # Resources
#
# - [Intro to LangKit Example](https://github.com/whylabs/langkit/blob/main/langkit/examples/Intro_to_Langkit.ipynb)
# - [LangKit + LangChain Integration](https://github.com/whylabs/langkit/blob/main/langkit/examples/Langchain_OpenAI_LLM_Monitoring_with_WhyLabs.ipynb)
# - [LangKit GitHub](https://github.com/whylabs/langkit)
# - [whylogs GitHub](https://github.com/whylabs/whylogs)
# - [WhyLabs](https://whylabs.ai/safeguard-large-language-models)
# - [Hugging Face GPT2 Model](https://huggingface.co/gpt2)
# - [LangKit onboarding](https://docs.whylabs.ai/docs/whylabs-onboarding/)
# - [WhyLabs API](https://docs.whylabs.ai/docs/whylabs-api/)
# - [LangKit integration to the cloud](https://docs.whylabs.ai/docs/integrations-cloud/#aws)
